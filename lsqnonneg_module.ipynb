# %%
# Date:2018.07.21
# Author: Runyu Zhang

# %%
# %load_ext memory_profiler
import numpy as np
import torch
import torch.nn as nn
from torch.autograd import Variable
from torch.autograd.function import once_differentiable
from scipy.optimize import nnls

# %%
class LsqNonnegF(torch.autograd.Function):
    '''
    Define the forward and backward process for q(X,A) = argmin_{S >= 0} ||X - AS||_F^2
    '''
    @staticmethod
    def forward(ctx, input, A):
        print("begin forward")
        # %memit
        # note that here the input X have size(n,m)
        # output should have size(n, k)
        # A should have size(k,m) and what we are actually doing is:
        # min_{S >= 0} ||X - S*A||_F^2
        # output[i,:] = argmin_{s >= 0} ||X[i,:] - s*A||_F^2 
        # this is slightly different from what we do in NMF
        [output, res] = lsqnonneg_tensor_version(A.data.t(), input.data.t())
        # %memit
        # normalize the output
        #output_sum = torch.sum(output, dim =1) + 1e-10
        #output = output.t()/output_sum
        #output = output.t()
        #A.data = A.data.t()*output_sum
        #A.data = A.data.t()
        ctx.save_for_backward(input, A)
        # %memit
        output = output.t()
        # %memit
        ctx.intermediate = output
        # %memit
        print("end forward")
        return output
    
    @staticmethod
    @once_differentiable # don't know if this is needed, it seems like if without this line then in backprop all the operations should be differentiable
    def backward(ctx, grad_output):
        input, A = ctx.saved_tensors
        grad_input = grad_A = None
        output = ctx.intermediate
        if ctx.needs_input_grad[0]:
            grad_input = calc_grad_X(grad_output.t(), A.t().data, output.t())# calculate gradient with respect to X
            grad_input = grad_input.t()
        if ctx.needs_input_grad[1]:
            grad_A = calc_grad_A(grad_output.t(), A.t().data, output.t(), input.t().data) # calculate gradient with respect to A
            grad_A = grad_A.t()
        return grad_input, grad_A

# %%
def lsqnonneg_tensor_version(C, D):
    
    C = C.numpy() # Transforming to numpy array size(n,k)
    D = D.numpy() # size(n,m)
    n = D.shape[0]
    m = D.shape[1]
    k = C.shape[1]
    X = np.zeros([k,m])
    res_total = 0
    for i in range(m):
        d = D[:,i]
        [x, res] = nnls(C, d)
        res_total += res
        X[:,i] = x
    X = torch.from_numpy(X).double() # Transforming to torch Tensor
    return X, res_total

# %%
def calc_grad_X(grad_S, A, S):
    A_np = A.numpy()
    S_np = S.numpy()
    grad_S_np = grad_S.numpy()
    n = A.shape[0]
    k = A.shape[1]
    m = S.shape[1]
    grad_X = np.zeros([n,m])
    for i in range(m):
        s = S_np[:,i]
        supp = s!=0
        grad_s_supp = grad_S_np[supp,i]
        A_supp = A_np[:,supp]
        grad_X[:,i] = np.linalg.pinv(A_supp).T@grad_s_supp
    grad_X = torch.from_numpy(grad_X).double()
    return grad_X

# %%
def calc_grad_A(grad_S, A, S, X):
    A_np = A.numpy()
    S_np = S.numpy()
    grad_S_np = grad_S.numpy()
    X_np = X.numpy()
    n = A.shape[0]
    k = A.shape[1]
    m = S.shape[1]
    grad_A = np.zeros([n,k])
    for l in range(m):
        s = S_np[:,l]
        supp = s!=0
        A_supp = A_np[:,supp]
        grad_s_supp = grad_S_np[supp,l:l+1]
        x = X_np[:,l:l+1]
        A_supp_inv = np.linalg.pinv(A_supp)
        part1 = -(A_supp_inv.T@grad_s_supp)@(x.T@A_supp_inv.T)
        part2 = (x - A_supp@(A_supp_inv@x))@((grad_s_supp.T@A_supp_inv)@A_supp_inv.T)
        grad_A[:,supp] += part1 + part2
    grad_A = torch.from_numpy(grad_A).double()
    return grad_A

# %%
class LsqNonneg(nn.Module):
    def __init__(self, m, k, initial_A = None):
        super(LsqNonneg, self).__init__()
        self.m = m;
        self.k = k;
        self.A = nn.Parameter(torch.DoubleTensor(k,m))
        if initial_A is None:
            self.A.data = torch.abs(torch.randn(k,m,dtype = torch.double)) # initialize the network parameter
        else:
            self.A.data = initial_A
    
    #todo:remove it
    def __del__(self):
        print("removed")
        self.A = None
    def forward(self, input_obj):
        return LsqNonnegF.apply(input_obj, self.A)
        #input() is a function

# %%
# from torch.autograd import gradcheck

# %%
# n = 10
# m = 10
# k = 5
# X_tensor = torch.randn(n,m, dtype = torch.double)
# A_tensor = torch.randn(k,m, dtype = torch.double)

# %%
# X = Variable(X_tensor, requires_grad=True)
# A = Variable(A_tensor, requires_grad = True)
# X = torch.abs(X)
# A = torch.abs(A)
# input = (X, A)
# test = gradcheck(LsqNonnegF().apply, input, eps = 1e-6, atol = 0, rtol = 1e-9)
# print(test)

# %%
# debugging memory problems
m = 130000
net = LsqNonneg(m, 20)
for i in range(100):
    # %memit
    inputs = Variable(torch.randn(10, m))
    # %memit
    S = net(inputs)
    # %memit
    #loss = torch.sum(S)
    #loss.backward()
    # %memit
    print("=========")
# Out:
# peak memory: 116.22 MiB, increment: 0.05 MiB
# peak memory: 121.26 MiB, increment: 0.02 MiB
# begin forward
# peak memory: 121.32 MiB, increment: 0.03 MiB
# peak memory: 121.53 MiB, increment: 0.00 MiB
# peak memory: 121.53 MiB, increment: 0.00 MiB
# peak memory: 121.53 MiB, increment: 0.00 MiB
# peak memory: 121.53 MiB, increment: 0.00 MiB
# end forward
# peak memory: 121.55 MiB, increment: 0.00 MiB
# peak memory: 121.52 MiB, increment: -0.03 MiB
# =========
# peak memory: 121.52 MiB, increment: 0.00 MiB
# peak memory: 126.50 MiB, increment: 0.02 MiB
# begin forward
# peak memory: 126.50 MiB, increment: 0.00 MiB
# peak memory: 126.49 MiB, increment: 0.00 MiB
# peak memory: 126.49 MiB, increment: 0.00 MiB
# peak memory: 126.49 MiB, increment: 0.00 MiB
# peak memory: 126.49 MiB, increment: 0.00 MiB
# end forward
# peak memory: 126.49 MiB, increment: 0.00 MiB
# peak memory: 126.49 MiB, increment: 0.00 MiB
# =========
# peak memory: 126.49 MiB, increment: 0.00 MiB
# peak memory: 131.45 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 131.45 MiB, increment: 0.00 MiB
# peak memory: 131.45 MiB, increment: 0.00 MiB
# peak memory: 131.45 MiB, increment: 0.00 MiB
# peak memory: 131.45 MiB, increment: 0.00 MiB
# peak memory: 131.45 MiB, increment: 0.00 MiB
# end forward
# peak memory: 131.45 MiB, increment: 0.00 MiB
# peak memory: 131.45 MiB, increment: 0.00 MiB
# =========
# peak memory: 131.45 MiB, increment: 0.00 MiB
# peak memory: 136.41 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 136.41 MiB, increment: 0.00 MiB
# peak memory: 136.41 MiB, increment: 0.00 MiB
# peak memory: 136.41 MiB, increment: 0.00 MiB
# peak memory: 136.41 MiB, increment: 0.00 MiB
# peak memory: 136.41 MiB, increment: 0.00 MiB
# end forward
# peak memory: 136.41 MiB, increment: 0.00 MiB
# peak memory: 136.41 MiB, increment: 0.00 MiB
# =========
# peak memory: 136.41 MiB, increment: 0.00 MiB
# peak memory: 141.37 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 141.37 MiB, increment: 0.00 MiB
# peak memory: 141.36 MiB, increment: 0.00 MiB
# peak memory: 141.36 MiB, increment: 0.00 MiB
# peak memory: 141.38 MiB, increment: 0.01 MiB
# peak memory: 141.38 MiB, increment: 0.00 MiB
# end forward
# peak memory: 141.38 MiB, increment: 0.00 MiB
# peak memory: 141.38 MiB, increment: 0.00 MiB
# =========
# peak memory: 141.38 MiB, increment: 0.00 MiB
# peak memory: 146.34 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 146.34 MiB, increment: 0.00 MiB
# peak memory: 146.34 MiB, increment: 0.00 MiB
# peak memory: 146.34 MiB, increment: 0.00 MiB
# peak memory: 146.34 MiB, increment: 0.00 MiB
# peak memory: 146.34 MiB, increment: 0.00 MiB
# end forward
# peak memory: 146.34 MiB, increment: 0.00 MiB
# peak memory: 146.34 MiB, increment: 0.00 MiB
# =========
# peak memory: 146.34 MiB, increment: 0.00 MiB
# peak memory: 151.32 MiB, increment: 0.02 MiB
# begin forward
# peak memory: 151.32 MiB, increment: 0.00 MiB
# peak memory: 151.32 MiB, increment: 0.00 MiB
# peak memory: 151.32 MiB, increment: 0.00 MiB
# peak memory: 151.32 MiB, increment: 0.00 MiB
# peak memory: 151.32 MiB, increment: 0.00 MiB
# end forward
# peak memory: 151.32 MiB, increment: 0.00 MiB
# peak memory: 151.32 MiB, increment: 0.00 MiB
# =========
# peak memory: 151.34 MiB, increment: 0.02 MiB
# peak memory: 143.08 MiB, increment: -13.23 MiB
# begin forward
# peak memory: 143.09 MiB, increment: 0.00 MiB
# peak memory: 143.09 MiB, increment: 0.00 MiB
# peak memory: 143.09 MiB, increment: 0.00 MiB
# peak memory: 143.09 MiB, increment: 0.00 MiB
# peak memory: 143.09 MiB, increment: 0.00 MiB
# end forward
# peak memory: 143.09 MiB, increment: 0.00 MiB
# peak memory: 143.09 MiB, increment: 0.00 MiB
# =========
# peak memory: 143.09 MiB, increment: 0.00 MiB
# peak memory: 148.05 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 148.05 MiB, increment: 0.00 MiB
# peak memory: 148.04 MiB, increment: 0.00 MiB
# peak memory: 148.04 MiB, increment: 0.00 MiB
# peak memory: 148.04 MiB, increment: 0.00 MiB
# peak memory: 148.04 MiB, increment: 0.00 MiB
# end forward
# peak memory: 148.04 MiB, increment: 0.00 MiB
# peak memory: 148.04 MiB, increment: 0.00 MiB
# =========
# peak memory: 148.04 MiB, increment: 0.00 MiB
# peak memory: 153.00 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 153.00 MiB, increment: 0.00 MiB
# peak memory: 153.00 MiB, increment: 0.00 MiB
# peak memory: 153.00 MiB, increment: 0.00 MiB
# peak memory: 153.00 MiB, increment: 0.00 MiB
# peak memory: 153.00 MiB, increment: 0.00 MiB
# end forward
# peak memory: 153.00 MiB, increment: 0.00 MiB
# peak memory: 153.00 MiB, increment: 0.00 MiB
# =========
# peak memory: 153.01 MiB, increment: 0.00 MiB
# peak memory: 157.97 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 157.97 MiB, increment: 0.00 MiB
# peak memory: 157.97 MiB, increment: 0.00 MiB
# peak memory: 157.97 MiB, increment: 0.00 MiB
# peak memory: 157.97 MiB, increment: 0.00 MiB
# peak memory: 157.97 MiB, increment: 0.00 MiB
# end forward
# peak memory: 157.97 MiB, increment: 0.00 MiB
# peak memory: 157.97 MiB, increment: 0.00 MiB
# =========
# peak memory: 157.97 MiB, increment: 0.00 MiB
# peak memory: 162.93 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 162.93 MiB, increment: 0.00 MiB
# peak memory: 162.93 MiB, increment: 0.00 MiB
# peak memory: 162.93 MiB, increment: 0.00 MiB
# peak memory: 162.93 MiB, increment: 0.00 MiB
# peak memory: 162.93 MiB, increment: 0.00 MiB
# end forward
# peak memory: 162.93 MiB, increment: 0.00 MiB
# peak memory: 162.93 MiB, increment: 0.00 MiB
# =========
# peak memory: 162.93 MiB, increment: 0.00 MiB
# peak memory: 167.89 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 135.89 MiB, increment: 0.00 MiB
# peak memory: 135.90 MiB, increment: 0.00 MiB
# peak memory: 135.90 MiB, increment: 0.00 MiB
# peak memory: 135.90 MiB, increment: 0.00 MiB
# peak memory: 135.91 MiB, increment: 0.01 MiB
# end forward
# peak memory: 135.91 MiB, increment: 0.00 MiB
# peak memory: 135.91 MiB, increment: 0.00 MiB
# =========
# peak memory: 135.91 MiB, increment: 0.00 MiB
# peak memory: 140.87 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 140.87 MiB, increment: 0.00 MiB
# peak memory: 140.91 MiB, increment: 0.00 MiB
# peak memory: 140.91 MiB, increment: 0.00 MiB
# peak memory: 140.91 MiB, increment: 0.00 MiB
# peak memory: 140.91 MiB, increment: 0.00 MiB
# end forward
# peak memory: 140.91 MiB, increment: 0.00 MiB
# peak memory: 140.91 MiB, increment: 0.00 MiB
# =========
# peak memory: 140.91 MiB, increment: 0.00 MiB
# peak memory: 145.88 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 145.88 MiB, increment: 0.00 MiB
# peak memory: 145.86 MiB, increment: 0.00 MiB
# peak memory: 145.86 MiB, increment: 0.00 MiB
# peak memory: 145.86 MiB, increment: 0.00 MiB
# peak memory: 145.86 MiB, increment: 0.00 MiB
# end forward
# peak memory: 145.86 MiB, increment: 0.00 MiB
# peak memory: 145.86 MiB, increment: 0.00 MiB
# =========
# peak memory: 145.86 MiB, increment: 0.00 MiB
# peak memory: 150.82 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 150.82 MiB, increment: 0.00 MiB
# peak memory: 150.84 MiB, increment: 0.00 MiB
# peak memory: 150.84 MiB, increment: 0.00 MiB
# peak memory: 150.84 MiB, increment: 0.00 MiB
# peak memory: 150.84 MiB, increment: 0.00 MiB
# end forward
# peak memory: 150.84 MiB, increment: 0.00 MiB
# peak memory: 150.84 MiB, increment: 0.00 MiB
# =========
# peak memory: 150.84 MiB, increment: 0.00 MiB
# peak memory: 155.80 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 155.80 MiB, increment: 0.00 MiB
# peak memory: 155.82 MiB, increment: 0.00 MiB
# peak memory: 155.82 MiB, increment: 0.00 MiB
# peak memory: 155.82 MiB, increment: 0.00 MiB
# peak memory: 155.82 MiB, increment: 0.00 MiB
# end forward
# peak memory: 155.82 MiB, increment: 0.00 MiB
# peak memory: 155.82 MiB, increment: 0.00 MiB
# =========
# peak memory: 155.82 MiB, increment: 0.00 MiB
# peak memory: 131.01 MiB, increment: -29.77 MiB
# begin forward
# peak memory: 131.01 MiB, increment: 0.00 MiB
# peak memory: 131.01 MiB, increment: 0.00 MiB
# peak memory: 131.01 MiB, increment: 0.00 MiB
# peak memory: 131.01 MiB, increment: 0.00 MiB
# peak memory: 131.01 MiB, increment: 0.00 MiB
# end forward
# peak memory: 131.01 MiB, increment: 0.00 MiB
# peak memory: 131.01 MiB, increment: 0.00 MiB
# =========
# peak memory: 131.01 MiB, increment: 0.00 MiB
# peak memory: 135.97 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 135.97 MiB, increment: 0.00 MiB
# peak memory: 135.97 MiB, increment: 0.00 MiB
# peak memory: 135.97 MiB, increment: 0.00 MiB
# peak memory: 135.97 MiB, increment: 0.00 MiB
# peak memory: 135.97 MiB, increment: 0.00 MiB
# end forward
# peak memory: 135.98 MiB, increment: 0.00 MiB
# peak memory: 135.98 MiB, increment: 0.00 MiB
# =========
# peak memory: 135.98 MiB, increment: 0.00 MiB
# peak memory: 140.94 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 140.94 MiB, increment: 0.00 MiB
# peak memory: 140.94 MiB, increment: 0.00 MiB
# peak memory: 133.05 MiB, increment: -7.88 MiB
# peak memory: 133.05 MiB, increment: 0.00 MiB
# peak memory: 133.05 MiB, increment: 0.00 MiB
# end forward
# peak memory: 133.06 MiB, increment: 0.00 MiB
# peak memory: 133.06 MiB, increment: 0.00 MiB
# =========
# peak memory: 133.06 MiB, increment: 0.00 MiB
# peak memory: 138.02 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 138.03 MiB, increment: 0.00 MiB
# peak memory: 138.03 MiB, increment: 0.00 MiB
# peak memory: 138.03 MiB, increment: 0.00 MiB
# peak memory: 138.03 MiB, increment: 0.00 MiB
# peak memory: 138.03 MiB, increment: 0.00 MiB
# end forward
# peak memory: 138.03 MiB, increment: 0.00 MiB
# peak memory: 138.03 MiB, increment: 0.00 MiB
# =========
# peak memory: 138.03 MiB, increment: 0.00 MiB
# peak memory: 142.99 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 142.99 MiB, increment: 0.00 MiB
# peak memory: 142.99 MiB, increment: 0.00 MiB
# peak memory: 143.00 MiB, increment: 0.00 MiB
# peak memory: 143.00 MiB, increment: 0.00 MiB
# peak memory: 143.00 MiB, increment: 0.00 MiB
# end forward
# peak memory: 143.00 MiB, increment: 0.00 MiB
# peak memory: 118.82 MiB, increment: -24.18 MiB
# =========
# peak memory: 105.73 MiB, increment: 0.00 MiB
# peak memory: 110.75 MiB, increment: 0.06 MiB
# begin forward
# peak memory: 110.78 MiB, increment: 0.02 MiB
# peak memory: 110.78 MiB, increment: 0.01 MiB
# peak memory: 110.78 MiB, increment: 0.00 MiB
# peak memory: 110.78 MiB, increment: 0.00 MiB
# peak memory: 110.78 MiB, increment: 0.00 MiB
# end forward
# peak memory: 110.78 MiB, increment: 0.00 MiB
# peak memory: 110.78 MiB, increment: 0.00 MiB
# =========
# peak memory: 110.78 MiB, increment: 0.00 MiB
# peak memory: 115.74 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 115.74 MiB, increment: 0.00 MiB
# peak memory: 115.75 MiB, increment: 0.01 MiB
# peak memory: 115.75 MiB, increment: 0.00 MiB
# peak memory: 115.75 MiB, increment: 0.00 MiB
# peak memory: 115.75 MiB, increment: 0.00 MiB
# end forward
# peak memory: 115.75 MiB, increment: 0.00 MiB
# peak memory: 115.75 MiB, increment: 0.00 MiB
# =========
# peak memory: 115.75 MiB, increment: 0.00 MiB
# peak memory: 120.71 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 107.73 MiB, increment: -12.98 MiB
# peak memory: 107.74 MiB, increment: 0.01 MiB
# peak memory: 107.74 MiB, increment: 0.00 MiB
# peak memory: 107.74 MiB, increment: 0.00 MiB
# peak memory: 107.74 MiB, increment: 0.00 MiB
# end forward
# peak memory: 107.74 MiB, increment: 0.00 MiB
# peak memory: 107.74 MiB, increment: 0.00 MiB
# =========
# peak memory: 107.74 MiB, increment: 0.00 MiB
# peak memory: 112.70 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 112.70 MiB, increment: 0.00 MiB
# peak memory: 112.71 MiB, increment: 0.01 MiB
# peak memory: 112.71 MiB, increment: 0.00 MiB
# peak memory: 112.72 MiB, increment: 0.00 MiB
# peak memory: 112.72 MiB, increment: 0.00 MiB
# end forward
# peak memory: 112.72 MiB, increment: 0.00 MiB
# peak memory: 112.72 MiB, increment: 0.00 MiB
# =========
# peak memory: 112.72 MiB, increment: 0.00 MiB
# peak memory: 117.68 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 117.68 MiB, increment: 0.00 MiB
# peak memory: 117.70 MiB, increment: 0.00 MiB
# peak memory: 117.70 MiB, increment: 0.00 MiB
# peak memory: 117.70 MiB, increment: 0.00 MiB
# peak memory: 117.70 MiB, increment: 0.00 MiB
# end forward
# peak memory: 117.70 MiB, increment: 0.00 MiB
# peak memory: 106.09 MiB, increment: -11.61 MiB
# =========
# peak memory: 100.44 MiB, increment: -5.65 MiB
# peak memory: 105.40 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 105.40 MiB, increment: 0.00 MiB
# peak memory: 105.41 MiB, increment: 0.01 MiB
# peak memory: 105.41 MiB, increment: 0.00 MiB
# peak memory: 105.41 MiB, increment: 0.00 MiB
# peak memory: 105.41 MiB, increment: 0.00 MiB
# end forward
# peak memory: 105.41 MiB, increment: 0.00 MiB
# peak memory: 105.41 MiB, increment: 0.00 MiB
# =========
# peak memory: 105.41 MiB, increment: 0.00 MiB
# peak memory: 110.38 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 110.38 MiB, increment: 0.00 MiB
# peak memory: 110.40 MiB, increment: 0.01 MiB
# peak memory: 110.41 MiB, increment: 0.00 MiB
# peak memory: 110.41 MiB, increment: 0.00 MiB
# peak memory: 110.41 MiB, increment: 0.00 MiB
# end forward
# peak memory: 110.41 MiB, increment: 0.00 MiB
# peak memory: 110.41 MiB, increment: 0.00 MiB
# =========
# peak memory: 89.71 MiB, increment: -20.70 MiB
# peak memory: 94.68 MiB, increment: 0.02 MiB
# begin forward
# peak memory: 94.69 MiB, increment: 0.00 MiB
# peak memory: 94.70 MiB, increment: 0.00 MiB
# peak memory: 94.70 MiB, increment: 0.00 MiB
# peak memory: 94.70 MiB, increment: 0.00 MiB
# peak memory: 94.70 MiB, increment: 0.00 MiB
# end forward
# peak memory: 94.70 MiB, increment: 0.00 MiB
# peak memory: 94.70 MiB, increment: 0.00 MiB
# =========
# peak memory: 94.70 MiB, increment: 0.00 MiB
# peak memory: 99.66 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 99.67 MiB, increment: 0.01 MiB
# peak memory: 99.67 MiB, increment: 0.00 MiB
# peak memory: 99.67 MiB, increment: 0.00 MiB
# peak memory: 99.67 MiB, increment: 0.00 MiB
# peak memory: 99.67 MiB, increment: 0.00 MiB
# end forward
# peak memory: 99.68 MiB, increment: 0.01 MiB
# peak memory: 99.68 MiB, increment: 0.00 MiB
# =========
# peak memory: 99.68 MiB, increment: 0.00 MiB
# peak memory: 104.64 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 104.65 MiB, increment: 0.00 MiB
# peak memory: 104.65 MiB, increment: 0.00 MiB
# peak memory: 104.66 MiB, increment: 0.00 MiB
# peak memory: 104.66 MiB, increment: 0.00 MiB
# peak memory: 104.66 MiB, increment: 0.00 MiB
# end forward
# peak memory: 104.66 MiB, increment: 0.00 MiB
# peak memory: 104.66 MiB, increment: 0.00 MiB
# =========
# peak memory: 104.66 MiB, increment: 0.00 MiB
# peak memory: 104.50 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 104.54 MiB, increment: 0.04 MiB
# peak memory: 104.57 MiB, increment: 0.03 MiB
# peak memory: 104.58 MiB, increment: 0.00 MiB
# peak memory: 104.59 MiB, increment: 0.02 MiB
# peak memory: 104.59 MiB, increment: 0.00 MiB
# end forward
# peak memory: 105.84 MiB, increment: 1.24 MiB
# peak memory: 105.84 MiB, increment: 0.00 MiB
# =========
# peak memory: 105.84 MiB, increment: 0.00 MiB
# peak memory: 110.80 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 110.81 MiB, increment: 0.00 MiB
# peak memory: 110.84 MiB, increment: 0.00 MiB
# peak memory: 110.85 MiB, increment: 0.00 MiB
# peak memory: 110.85 MiB, increment: 0.00 MiB
# peak memory: 110.85 MiB, increment: 0.00 MiB
# end forward
# peak memory: 91.12 MiB, increment: -19.73 MiB
# peak memory: 91.12 MiB, increment: 0.00 MiB
# =========
# peak memory: 91.12 MiB, increment: 0.00 MiB
# peak memory: 96.09 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 96.09 MiB, increment: 0.00 MiB
# peak memory: 96.09 MiB, increment: 0.00 MiB
# peak memory: 96.09 MiB, increment: 0.00 MiB
# peak memory: 96.09 MiB, increment: 0.00 MiB
# peak memory: 96.09 MiB, increment: 0.00 MiB
# end forward
# peak memory: 96.09 MiB, increment: 0.00 MiB
# peak memory: 96.09 MiB, increment: 0.00 MiB
# =========
# peak memory: 96.09 MiB, increment: -0.00 MiB
# peak memory: 101.05 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 101.05 MiB, increment: 0.00 MiB
# peak memory: 101.06 MiB, increment: 0.00 MiB
# peak memory: 101.06 MiB, increment: 0.00 MiB
# peak memory: 101.06 MiB, increment: 0.00 MiB
# peak memory: 101.06 MiB, increment: 0.00 MiB
# end forward
# peak memory: 101.06 MiB, increment: 0.00 MiB
# peak memory: 101.06 MiB, increment: 0.00 MiB
# =========
# peak memory: 101.06 MiB, increment: 0.00 MiB
# peak memory: 106.03 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 106.03 MiB, increment: 0.00 MiB
# peak memory: 106.04 MiB, increment: 0.01 MiB
# peak memory: 106.04 MiB, increment: 0.00 MiB
# peak memory: 106.04 MiB, increment: 0.00 MiB
# peak memory: 106.04 MiB, increment: 0.00 MiB
# end forward
# peak memory: 106.04 MiB, increment: 0.00 MiB
# peak memory: 106.04 MiB, increment: 0.00 MiB
# =========
# peak memory: 106.04 MiB, increment: 0.00 MiB
# peak memory: 111.01 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 111.01 MiB, increment: 0.00 MiB
# peak memory: 111.01 MiB, increment: 0.00 MiB
# peak memory: 111.01 MiB, increment: 0.00 MiB
# peak memory: 111.01 MiB, increment: 0.00 MiB
# peak memory: 111.01 MiB, increment: 0.00 MiB
# end forward
# peak memory: 111.01 MiB, increment: 0.00 MiB
# peak memory: 111.01 MiB, increment: 0.00 MiB
# =========
# peak memory: 111.01 MiB, increment: 0.00 MiB
# peak memory: 115.97 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 115.97 MiB, increment: 0.00 MiB
# peak memory: 116.00 MiB, increment: 0.03 MiB
# peak memory: 116.00 MiB, increment: 0.00 MiB
# peak memory: 116.00 MiB, increment: 0.01 MiB
# peak memory: 116.00 MiB, increment: 0.00 MiB
# end forward
# peak memory: 116.01 MiB, increment: 0.00 MiB
# peak memory: 116.01 MiB, increment: 0.00 MiB
# =========
# peak memory: 116.01 MiB, increment: 0.00 MiB
# peak memory: 120.98 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 120.98 MiB, increment: 0.00 MiB
# peak memory: 120.98 MiB, increment: 0.00 MiB
# peak memory: 120.98 MiB, increment: 0.00 MiB
# peak memory: 120.98 MiB, increment: 0.00 MiB
# peak memory: 120.98 MiB, increment: 0.00 MiB
# end forward
# peak memory: 120.98 MiB, increment: 0.00 MiB
# peak memory: 120.98 MiB, increment: 0.00 MiB
# =========
# peak memory: 120.98 MiB, increment: 0.00 MiB
# peak memory: 125.95 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 125.95 MiB, increment: 0.00 MiB
# peak memory: 125.95 MiB, increment: 0.00 MiB
# peak memory: 125.95 MiB, increment: 0.00 MiB
# peak memory: 125.95 MiB, increment: 0.00 MiB
# peak memory: 125.95 MiB, increment: 0.00 MiB
# end forward
# peak memory: 125.95 MiB, increment: 0.00 MiB
# peak memory: 125.95 MiB, increment: 0.00 MiB
# =========
# peak memory: 125.95 MiB, increment: 0.00 MiB
# peak memory: 130.91 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 130.91 MiB, increment: 0.00 MiB
# peak memory: 130.93 MiB, increment: 0.00 MiB
# peak memory: 130.94 MiB, increment: 0.00 MiB
# peak memory: 130.94 MiB, increment: 0.00 MiB
# peak memory: 130.94 MiB, increment: 0.00 MiB
# end forward
# peak memory: 130.94 MiB, increment: 0.00 MiB
# peak memory: 130.94 MiB, increment: 0.00 MiB
# =========
# peak memory: 130.94 MiB, increment: 0.00 MiB
# peak memory: 135.90 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 135.90 MiB, increment: 0.00 MiB
# peak memory: 135.89 MiB, increment: 0.00 MiB
# peak memory: 135.90 MiB, increment: 0.00 MiB
# peak memory: 135.90 MiB, increment: 0.00 MiB
# peak memory: 135.90 MiB, increment: 0.00 MiB
# end forward
# peak memory: 135.90 MiB, increment: 0.00 MiB
# peak memory: 135.90 MiB, increment: 0.00 MiB
# =========
# peak memory: 135.90 MiB, increment: 0.00 MiB
# peak memory: 140.86 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 140.86 MiB, increment: 0.00 MiB
# peak memory: 140.87 MiB, increment: 0.00 MiB
# peak memory: 140.88 MiB, increment: 0.00 MiB
# peak memory: 140.88 MiB, increment: 0.00 MiB
# peak memory: 140.88 MiB, increment: 0.00 MiB
# end forward
# peak memory: 140.88 MiB, increment: 0.00 MiB
# peak memory: 140.88 MiB, increment: 0.00 MiB
# =========
# peak memory: 140.88 MiB, increment: 0.00 MiB
# peak memory: 145.84 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 145.84 MiB, increment: 0.00 MiB
# peak memory: 145.83 MiB, increment: 0.00 MiB
# peak memory: 145.84 MiB, increment: 0.00 MiB
# peak memory: 145.84 MiB, increment: 0.00 MiB
# peak memory: 145.84 MiB, increment: 0.00 MiB
# end forward
# peak memory: 145.84 MiB, increment: 0.00 MiB
# peak memory: 145.84 MiB, increment: 0.00 MiB
# =========
# peak memory: 145.84 MiB, increment: 0.00 MiB
# peak memory: 150.80 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 150.80 MiB, increment: 0.00 MiB
# peak memory: 150.79 MiB, increment: 0.00 MiB
# peak memory: 150.80 MiB, increment: 0.00 MiB
# peak memory: 150.80 MiB, increment: 0.00 MiB
# peak memory: 150.80 MiB, increment: 0.00 MiB
# end forward
# peak memory: 150.80 MiB, increment: 0.00 MiB
# peak memory: 150.80 MiB, increment: 0.00 MiB
# =========
# peak memory: 150.80 MiB, increment: 0.00 MiB
# peak memory: 155.76 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 155.76 MiB, increment: 0.00 MiB
# peak memory: 155.76 MiB, increment: 0.00 MiB
# peak memory: 155.76 MiB, increment: 0.00 MiB
# peak memory: 155.76 MiB, increment: 0.00 MiB
# peak memory: 155.76 MiB, increment: 0.00 MiB
# end forward
# peak memory: 155.76 MiB, increment: 0.00 MiB
# peak memory: 155.76 MiB, increment: 0.00 MiB
# =========
# peak memory: 155.76 MiB, increment: 0.00 MiB
# peak memory: 160.72 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 160.72 MiB, increment: 0.00 MiB
# peak memory: 160.72 MiB, increment: 0.00 MiB
# peak memory: 160.72 MiB, increment: 0.00 MiB
# peak memory: 160.72 MiB, increment: 0.00 MiB
# peak memory: 160.72 MiB, increment: 0.00 MiB
# end forward
# peak memory: 160.72 MiB, increment: 0.00 MiB
# peak memory: 160.72 MiB, increment: 0.00 MiB
# =========
# peak memory: 160.72 MiB, increment: 0.00 MiB
# peak memory: 165.68 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 165.68 MiB, increment: 0.00 MiB
# peak memory: 165.68 MiB, increment: 0.00 MiB
# peak memory: 165.68 MiB, increment: 0.00 MiB
# peak memory: 165.68 MiB, increment: 0.00 MiB
# peak memory: 165.68 MiB, increment: 0.00 MiB
# end forward
# peak memory: 165.68 MiB, increment: 0.00 MiB
# peak memory: 165.68 MiB, increment: 0.00 MiB
# =========
# peak memory: 165.68 MiB, increment: 0.00 MiB
# peak memory: 170.64 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 170.64 MiB, increment: 0.00 MiB
# peak memory: 170.64 MiB, increment: 0.00 MiB
# peak memory: 170.64 MiB, increment: 0.00 MiB
# peak memory: 170.65 MiB, increment: 0.00 MiB
# peak memory: 170.65 MiB, increment: 0.00 MiB
# end forward
# peak memory: 170.65 MiB, increment: 0.00 MiB
# peak memory: 170.65 MiB, increment: 0.00 MiB
# =========
# peak memory: 170.65 MiB, increment: 0.00 MiB
# peak memory: 175.61 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 175.61 MiB, increment: 0.00 MiB
# peak memory: 175.61 MiB, increment: 0.00 MiB
# peak memory: 175.61 MiB, increment: 0.00 MiB
# peak memory: 175.61 MiB, increment: 0.00 MiB
# peak memory: 175.61 MiB, increment: 0.00 MiB
# end forward
# peak memory: 175.61 MiB, increment: 0.00 MiB
# peak memory: 175.61 MiB, increment: 0.00 MiB
# =========
# peak memory: 175.61 MiB, increment: 0.00 MiB
# peak memory: 180.58 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 180.58 MiB, increment: 0.00 MiB
# peak memory: 180.58 MiB, increment: 0.00 MiB
# peak memory: 180.58 MiB, increment: 0.00 MiB
# peak memory: 180.58 MiB, increment: 0.00 MiB
# peak memory: 180.58 MiB, increment: 0.00 MiB
# end forward
# peak memory: 180.58 MiB, increment: 0.00 MiB
# peak memory: 180.58 MiB, increment: 0.00 MiB
# =========
# peak memory: 148.62 MiB, increment: -31.96 MiB
# peak memory: 153.58 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 153.58 MiB, increment: 0.00 MiB
# peak memory: 153.57 MiB, increment: 0.00 MiB
# peak memory: 153.58 MiB, increment: 0.00 MiB
# peak memory: 153.58 MiB, increment: 0.00 MiB
# peak memory: 153.58 MiB, increment: 0.00 MiB
# end forward
# peak memory: 153.58 MiB, increment: 0.00 MiB
# peak memory: 153.58 MiB, increment: 0.00 MiB
# =========
# peak memory: 153.58 MiB, increment: 0.00 MiB
# peak memory: 158.54 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 158.55 MiB, increment: 0.00 MiB
# peak memory: 158.57 MiB, increment: 0.00 MiB
# peak memory: 100.48 MiB, increment: 0.00 MiB
# peak memory: 100.48 MiB, increment: 0.00 MiB
# peak memory: 100.48 MiB, increment: 0.00 MiB
# end forward
# peak memory: 100.48 MiB, increment: 0.00 MiB
# peak memory: 100.48 MiB, increment: 0.00 MiB
# =========
# peak memory: 100.49 MiB, increment: 0.00 MiB
# peak memory: 105.45 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 105.45 MiB, increment: 0.00 MiB
# peak memory: 105.45 MiB, increment: 0.00 MiB
# peak memory: 105.45 MiB, increment: 0.00 MiB
# peak memory: 105.45 MiB, increment: 0.00 MiB
# peak memory: 105.46 MiB, increment: 0.01 MiB
# end forward
# peak memory: 105.46 MiB, increment: 0.00 MiB
# peak memory: 105.46 MiB, increment: 0.00 MiB
# =========
# peak memory: 105.46 MiB, increment: 0.00 MiB
# peak memory: 110.42 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 110.42 MiB, increment: 0.00 MiB
# peak memory: 110.43 MiB, increment: 0.00 MiB
# peak memory: 110.43 MiB, increment: 0.00 MiB
# peak memory: 110.43 MiB, increment: -0.01 MiB
# peak memory: 110.44 MiB, increment: 0.01 MiB
# end forward
# peak memory: 110.44 MiB, increment: 0.00 MiB
# peak memory: 110.44 MiB, increment: 0.00 MiB
# =========
# peak memory: 110.44 MiB, increment: 0.00 MiB
# peak memory: 115.40 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 115.40 MiB, increment: 0.00 MiB
# peak memory: 115.40 MiB, increment: 0.00 MiB
# peak memory: 115.40 MiB, increment: 0.00 MiB
# peak memory: 115.40 MiB, increment: 0.00 MiB
# peak memory: 115.41 MiB, increment: 0.00 MiB
# end forward
# peak memory: 104.94 MiB, increment: -10.46 MiB
# peak memory: 104.94 MiB, increment: 0.00 MiB
# =========
# peak memory: 104.95 MiB, increment: 0.00 MiB
# peak memory: 109.91 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 109.91 MiB, increment: 0.00 MiB
# peak memory: 109.91 MiB, increment: 0.00 MiB
# peak memory: 109.91 MiB, increment: 0.00 MiB
# peak memory: 109.91 MiB, increment: 0.00 MiB
# peak memory: 109.91 MiB, increment: 0.00 MiB
# end forward
# peak memory: 109.91 MiB, increment: 0.00 MiB
# peak memory: 109.91 MiB, increment: 0.00 MiB
# =========
# peak memory: 109.93 MiB, increment: 0.02 MiB
# peak memory: 80.52 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 80.53 MiB, increment: 0.00 MiB
# peak memory: 80.54 MiB, increment: 0.00 MiB
# peak memory: 80.54 MiB, increment: 0.00 MiB
# peak memory: 80.54 MiB, increment: 0.00 MiB
# peak memory: 80.54 MiB, increment: 0.00 MiB
# end forward
# peak memory: 80.55 MiB, increment: 0.00 MiB
# peak memory: 80.55 MiB, increment: 0.00 MiB
# =========
# peak memory: 80.55 MiB, increment: 0.00 MiB
# peak memory: 85.51 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 85.51 MiB, increment: 0.00 MiB
# peak memory: 85.52 MiB, increment: 0.00 MiB
# peak memory: 85.52 MiB, increment: 0.00 MiB
# peak memory: 85.52 MiB, increment: 0.00 MiB
# peak memory: 85.52 MiB, increment: 0.00 MiB
# end forward
# peak memory: 85.52 MiB, increment: 0.00 MiB
# peak memory: 85.52 MiB, increment: 0.00 MiB
# =========
# peak memory: 85.52 MiB, increment: 0.00 MiB
# peak memory: 90.49 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 90.49 MiB, increment: 0.00 MiB
# peak memory: 90.50 MiB, increment: 0.00 MiB
# peak memory: 90.50 MiB, increment: 0.00 MiB
# peak memory: 90.50 MiB, increment: 0.00 MiB
# peak memory: 90.50 MiB, increment: 0.00 MiB
# end forward
# peak memory: 90.50 MiB, increment: 0.00 MiB
# peak memory: 90.50 MiB, increment: 0.00 MiB
# =========
# peak memory: 90.50 MiB, increment: 0.00 MiB
# peak memory: 95.46 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 95.46 MiB, increment: 0.00 MiB
# peak memory: 95.46 MiB, increment: 0.00 MiB
# peak memory: 95.47 MiB, increment: 0.00 MiB
# peak memory: 95.47 MiB, increment: 0.00 MiB
# peak memory: 95.47 MiB, increment: 0.00 MiB
# end forward
# peak memory: 95.47 MiB, increment: 0.00 MiB
# peak memory: 95.47 MiB, increment: 0.00 MiB
# =========
# peak memory: 94.84 MiB, increment: -0.62 MiB
# peak memory: 99.81 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 99.83 MiB, increment: 0.02 MiB
# peak memory: 99.84 MiB, increment: 0.00 MiB
# peak memory: 99.84 MiB, increment: 0.00 MiB
# peak memory: 99.84 MiB, increment: 0.00 MiB
# peak memory: 99.84 MiB, increment: 0.00 MiB
# end forward
# peak memory: 99.84 MiB, increment: 0.01 MiB
# peak memory: 99.84 MiB, increment: 0.00 MiB
# =========
# peak memory: 99.84 MiB, increment: 0.00 MiB
# peak memory: 104.80 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 104.80 MiB, increment: 0.00 MiB
# peak memory: 104.80 MiB, increment: 0.00 MiB
# peak memory: 104.80 MiB, increment: 0.00 MiB
# peak memory: 104.80 MiB, increment: 0.00 MiB
# peak memory: 104.80 MiB, increment: 0.00 MiB
# end forward
# peak memory: 104.81 MiB, increment: 0.01 MiB
# peak memory: 104.81 MiB, increment: 0.00 MiB
# =========
# peak memory: 104.81 MiB, increment: 0.00 MiB
# peak memory: 109.77 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 109.78 MiB, increment: 0.00 MiB
# peak memory: 109.78 MiB, increment: 0.00 MiB
# peak memory: 109.78 MiB, increment: 0.00 MiB
# peak memory: 109.78 MiB, increment: 0.00 MiB
# peak memory: 109.78 MiB, increment: 0.00 MiB
# end forward
# peak memory: 109.78 MiB, increment: 0.00 MiB
# peak memory: 109.78 MiB, increment: 0.00 MiB
# =========
# peak memory: 109.78 MiB, increment: 0.00 MiB
# peak memory: 114.74 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 114.74 MiB, increment: 0.00 MiB
# peak memory: 114.74 MiB, increment: 0.00 MiB
# peak memory: 114.74 MiB, increment: 0.00 MiB
# peak memory: 114.74 MiB, increment: 0.00 MiB
# peak memory: 114.74 MiB, increment: 0.00 MiB
# end forward
# peak memory: 114.74 MiB, increment: 0.00 MiB
# peak memory: 114.74 MiB, increment: 0.00 MiB
# =========
# peak memory: 114.74 MiB, increment: 0.00 MiB
# peak memory: 119.70 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 94.84 MiB, increment: -24.86 MiB
# peak memory: 94.85 MiB, increment: 0.00 MiB
# peak memory: 94.85 MiB, increment: 0.00 MiB
# peak memory: 94.86 MiB, increment: 0.00 MiB
# peak memory: 94.86 MiB, increment: 0.00 MiB
# end forward
# peak memory: 94.86 MiB, increment: 0.00 MiB
# peak memory: 94.87 MiB, increment: 0.00 MiB
# =========
# peak memory: 94.87 MiB, increment: 0.00 MiB
# peak memory: 99.86 MiB, increment: 0.03 MiB
# begin forward
# peak memory: 99.91 MiB, increment: 0.05 MiB
# peak memory: 99.91 MiB, increment: 0.00 MiB
# peak memory: 99.91 MiB, increment: 0.00 MiB
# peak memory: 99.92 MiB, increment: 0.01 MiB
# peak memory: 93.61 MiB, increment: -6.31 MiB
# end forward
# peak memory: 93.61 MiB, increment: 0.00 MiB
# peak memory: 93.61 MiB, increment: 0.00 MiB
# =========
# peak memory: 93.61 MiB, increment: 0.00 MiB
# peak memory: 98.58 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 98.58 MiB, increment: 0.00 MiB
# peak memory: 98.59 MiB, increment: 0.00 MiB
# peak memory: 98.59 MiB, increment: 0.00 MiB
# peak memory: 98.59 MiB, increment: 0.01 MiB
# peak memory: 98.59 MiB, increment: 0.00 MiB
# end forward
# peak memory: 98.59 MiB, increment: 0.00 MiB
# peak memory: 98.59 MiB, increment: 0.00 MiB
# =========
# peak memory: 98.60 MiB, increment: 0.00 MiB
# peak memory: 103.56 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 103.56 MiB, increment: 0.00 MiB
# peak memory: 103.56 MiB, increment: 0.00 MiB
# peak memory: 103.56 MiB, increment: 0.00 MiB
# peak memory: 103.56 MiB, increment: 0.00 MiB
# peak memory: 103.56 MiB, increment: 0.00 MiB
# end forward
# peak memory: 103.56 MiB, increment: 0.00 MiB
# peak memory: 103.56 MiB, increment: 0.00 MiB
# =========
# peak memory: 103.56 MiB, increment: 0.00 MiB
# peak memory: 108.52 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 108.52 MiB, increment: 0.00 MiB
# peak memory: 89.88 MiB, increment: -18.64 MiB
# peak memory: 89.88 MiB, increment: 0.00 MiB
# peak memory: 89.88 MiB, increment: 0.00 MiB
# peak memory: 89.88 MiB, increment: 0.00 MiB
# end forward
# peak memory: 89.88 MiB, increment: 0.00 MiB
# peak memory: 89.89 MiB, increment: 0.01 MiB
# =========
# peak memory: 89.89 MiB, increment: 0.00 MiB
# peak memory: 94.85 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 94.85 MiB, increment: 0.00 MiB
# peak memory: 94.87 MiB, increment: 0.00 MiB
# peak memory: 94.87 MiB, increment: 0.00 MiB
# peak memory: 94.87 MiB, increment: 0.00 MiB
# peak memory: 94.87 MiB, increment: 0.00 MiB
# end forward
# peak memory: 94.87 MiB, increment: 0.00 MiB
# peak memory: 94.88 MiB, increment: 0.01 MiB
# =========
# peak memory: 94.88 MiB, increment: 0.00 MiB
# peak memory: 99.84 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 99.84 MiB, increment: 0.00 MiB
# peak memory: 99.85 MiB, increment: 0.00 MiB
# peak memory: 99.85 MiB, increment: 0.00 MiB
# peak memory: 99.85 MiB, increment: 0.00 MiB
# peak memory: 99.85 MiB, increment: 0.00 MiB
# end forward
# peak memory: 99.85 MiB, increment: 0.00 MiB
# peak memory: 99.86 MiB, increment: 0.01 MiB
# =========
# peak memory: 99.86 MiB, increment: 0.00 MiB
# peak memory: 104.82 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 104.82 MiB, increment: 0.00 MiB
# peak memory: 104.86 MiB, increment: 0.00 MiB
# peak memory: 104.86 MiB, increment: 0.00 MiB
# peak memory: 104.86 MiB, increment: 0.00 MiB
# peak memory: 104.86 MiB, increment: 0.00 MiB
# end forward
# peak memory: 104.86 MiB, increment: 0.00 MiB
# peak memory: 104.86 MiB, increment: 0.00 MiB
# =========
# peak memory: 104.87 MiB, increment: 0.00 MiB
# peak memory: 109.83 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 109.83 MiB, increment: 0.00 MiB
# peak memory: 109.86 MiB, increment: 0.00 MiB
# peak memory: 109.86 MiB, increment: 0.00 MiB
# peak memory: 109.86 MiB, increment: 0.00 MiB
# peak memory: 109.86 MiB, increment: 0.00 MiB
# end forward
# peak memory: 109.86 MiB, increment: 0.00 MiB
# peak memory: 109.86 MiB, increment: 0.00 MiB
# =========
# peak memory: 90.99 MiB, increment: -18.87 MiB
# peak memory: 95.96 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 95.96 MiB, increment: 0.00 MiB
# peak memory: 95.99 MiB, increment: 0.00 MiB
# peak memory: 95.99 MiB, increment: 0.00 MiB
# peak memory: 95.99 MiB, increment: 0.00 MiB
# peak memory: 96.00 MiB, increment: 0.01 MiB
# end forward
# peak memory: 96.00 MiB, increment: 0.00 MiB
# peak memory: 96.00 MiB, increment: 0.00 MiB
# =========
# peak memory: 96.00 MiB, increment: 0.00 MiB
# peak memory: 100.96 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 100.96 MiB, increment: 0.00 MiB
# peak memory: 100.96 MiB, increment: 0.00 MiB
# peak memory: 100.96 MiB, increment: 0.00 MiB
# peak memory: 100.96 MiB, increment: 0.00 MiB
# peak memory: 100.97 MiB, increment: 0.00 MiB
# end forward
# peak memory: 100.99 MiB, increment: 0.01 MiB
# peak memory: 101.00 MiB, increment: 0.00 MiB
# =========
# peak memory: 101.00 MiB, increment: 0.00 MiB
# peak memory: 105.96 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 105.97 MiB, increment: 0.00 MiB
# peak memory: 105.96 MiB, increment: 0.00 MiB
# peak memory: 105.96 MiB, increment: 0.00 MiB
# peak memory: 105.96 MiB, increment: 0.00 MiB
# peak memory: 105.96 MiB, increment: 0.00 MiB
# end forward
# peak memory: 105.97 MiB, increment: 0.00 MiB
# peak memory: 105.97 MiB, increment: 0.00 MiB
# =========
# peak memory: 100.37 MiB, increment: -5.60 MiB
# peak memory: 105.33 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 105.33 MiB, increment: 0.00 MiB
# peak memory: 105.33 MiB, increment: 0.00 MiB
# peak memory: 105.33 MiB, increment: 0.00 MiB
# peak memory: 105.33 MiB, increment: 0.00 MiB
# peak memory: 105.33 MiB, increment: 0.00 MiB
# end forward
# peak memory: 105.33 MiB, increment: 0.00 MiB
# peak memory: 105.33 MiB, increment: 0.00 MiB
# =========
# peak memory: 105.33 MiB, increment: 0.00 MiB
# peak memory: 110.29 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 110.29 MiB, increment: 0.00 MiB
# peak memory: 110.30 MiB, increment: 0.00 MiB
# peak memory: 110.30 MiB, increment: 0.00 MiB
# peak memory: 110.30 MiB, increment: 0.00 MiB
# peak memory: 89.92 MiB, increment: -20.38 MiB
# end forward
# peak memory: 89.92 MiB, increment: 0.00 MiB
# peak memory: 89.92 MiB, increment: 0.00 MiB
# =========
# peak memory: 89.93 MiB, increment: 0.01 MiB
# peak memory: 94.89 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 94.89 MiB, increment: 0.00 MiB
# peak memory: 94.89 MiB, increment: 0.00 MiB
# peak memory: 94.89 MiB, increment: 0.00 MiB
# peak memory: 94.89 MiB, increment: 0.00 MiB
# peak memory: 94.89 MiB, increment: 0.00 MiB
# end forward
# peak memory: 94.89 MiB, increment: 0.00 MiB
# peak memory: 94.89 MiB, increment: 0.00 MiB
# =========
# peak memory: 94.89 MiB, increment: 0.00 MiB
# peak memory: 99.86 MiB, increment: 0.01 MiB
# begin forward
# peak memory: 99.86 MiB, increment: 0.00 MiB
# peak memory: 99.87 MiB, increment: 0.00 MiB
# peak memory: 99.87 MiB, increment: 0.00 MiB
# peak memory: 99.87 MiB, increment: 0.00 MiB
# peak memory: 99.87 MiB, increment: 0.00 MiB
# end forward
# peak memory: 99.86 MiB, increment: -0.01 MiB
# peak memory: 99.87 MiB, increment: 0.00 MiB
# =========
# peak memory: 99.87 MiB, increment: 0.00 MiB
# peak memory: 104.83 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 104.84 MiB, increment: 0.00 MiB
# peak memory: 104.85 MiB, increment: 0.00 MiB
# peak memory: 104.86 MiB, increment: 0.00 MiB
# peak memory: 104.86 MiB, increment: 0.00 MiB
# peak memory: 104.86 MiB, increment: 0.00 MiB
# end forward
# peak memory: 104.86 MiB, increment: 0.00 MiB
# peak memory: 104.86 MiB, increment: 0.00 MiB
# =========
# peak memory: 104.86 MiB, increment: 0.00 MiB
# peak memory: 109.82 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 109.82 MiB, increment: 0.00 MiB
# peak memory: 109.83 MiB, increment: 0.00 MiB
# peak memory: 109.83 MiB, increment: 0.00 MiB
# peak memory: 109.83 MiB, increment: 0.00 MiB
# peak memory: 109.83 MiB, increment: 0.00 MiB
# end forward
# peak memory: 109.84 MiB, increment: 0.00 MiB
# peak memory: 109.84 MiB, increment: 0.00 MiB
# =========
# peak memory: 109.84 MiB, increment: 0.00 MiB
# peak memory: 114.80 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 114.80 MiB, increment: 0.00 MiB
# peak memory: 114.82 MiB, increment: 0.00 MiB
# peak memory: 114.82 MiB, increment: 0.00 MiB
# peak memory: 114.82 MiB, increment: 0.00 MiB
# peak memory: 114.82 MiB, increment: 0.00 MiB
# end forward
# peak memory: 114.83 MiB, increment: 0.00 MiB
# peak memory: 114.83 MiB, increment: 0.00 MiB
# =========
# peak memory: 114.83 MiB, increment: 0.00 MiB
# peak memory: 119.79 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 119.79 MiB, increment: 0.00 MiB
# peak memory: 119.79 MiB, increment: 0.00 MiB
# peak memory: 119.79 MiB, increment: 0.00 MiB
# peak memory: 119.79 MiB, increment: 0.00 MiB
# peak memory: 119.80 MiB, increment: 0.00 MiB
# end forward
# peak memory: 119.80 MiB, increment: 0.00 MiB
# peak memory: 119.80 MiB, increment: 0.00 MiB
# =========
# peak memory: 119.80 MiB, increment: 0.00 MiB
# peak memory: 124.76 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 124.76 MiB, increment: 0.00 MiB
# peak memory: 124.76 MiB, increment: 0.00 MiB
# peak memory: 124.76 MiB, increment: 0.00 MiB
# peak memory: 124.76 MiB, increment: 0.00 MiB
# peak memory: 124.76 MiB, increment: 0.00 MiB
# end forward
# peak memory: 124.77 MiB, increment: 0.00 MiB
# peak memory: 124.77 MiB, increment: 0.00 MiB
# =========
# peak memory: 124.79 MiB, increment: 0.02 MiB
# peak memory: 129.76 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 129.76 MiB, increment: 0.00 MiB
# peak memory: 129.76 MiB, increment: 0.00 MiB
# peak memory: 129.76 MiB, increment: 0.00 MiB
# peak memory: 129.77 MiB, increment: 0.00 MiB
# peak memory: 129.77 MiB, increment: 0.00 MiB
# end forward
# peak memory: 129.77 MiB, increment: 0.00 MiB
# peak memory: 129.77 MiB, increment: 0.00 MiB
# =========
# peak memory: 129.77 MiB, increment: 0.00 MiB
# peak memory: 134.73 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 134.73 MiB, increment: 0.00 MiB
# peak memory: 134.73 MiB, increment: 0.00 MiB
# peak memory: 134.73 MiB, increment: 0.00 MiB
# peak memory: 134.73 MiB, increment: 0.00 MiB
# peak memory: 134.73 MiB, increment: 0.00 MiB
# end forward
# peak memory: 134.73 MiB, increment: 0.00 MiB
# peak memory: 134.73 MiB, increment: 0.00 MiB
# =========
# peak memory: 134.73 MiB, increment: 0.00 MiB
# peak memory: 89.86 MiB, increment: -49.83 MiB
# begin forward
# peak memory: 89.87 MiB, increment: 0.01 MiB
# peak memory: 89.95 MiB, increment: 0.00 MiB
# peak memory: 89.95 MiB, increment: 0.00 MiB
# peak memory: 89.96 MiB, increment: 0.00 MiB
# peak memory: 89.96 MiB, increment: 0.00 MiB
# end forward
# peak memory: 89.96 MiB, increment: 0.00 MiB
# peak memory: 89.96 MiB, increment: 0.00 MiB
# =========
# peak memory: 89.96 MiB, increment: 0.00 MiB
# peak memory: 94.93 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 94.93 MiB, increment: 0.01 MiB
# peak memory: 94.95 MiB, increment: 0.00 MiB
# peak memory: 94.95 MiB, increment: 0.00 MiB
# peak memory: 94.95 MiB, increment: 0.00 MiB
# peak memory: 94.95 MiB, increment: 0.00 MiB
# end forward
# peak memory: 94.95 MiB, increment: 0.00 MiB
# peak memory: 94.96 MiB, increment: 0.00 MiB
# =========
# peak memory: 94.96 MiB, increment: 0.00 MiB
# peak memory: 99.92 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 99.92 MiB, increment: 0.00 MiB
# peak memory: 99.93 MiB, increment: 0.00 MiB
# peak memory: 99.93 MiB, increment: 0.00 MiB
# peak memory: 99.93 MiB, increment: 0.00 MiB
# peak memory: 99.94 MiB, increment: 0.00 MiB
# end forward
# peak memory: 99.94 MiB, increment: 0.00 MiB
# peak memory: 99.94 MiB, increment: 0.00 MiB
# =========
# peak memory: 99.94 MiB, increment: 0.00 MiB
# peak memory: 104.90 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 104.91 MiB, increment: 0.00 MiB
# peak memory: 104.93 MiB, increment: 0.00 MiB
# peak memory: 104.93 MiB, increment: 0.00 MiB
# peak memory: 104.93 MiB, increment: 0.00 MiB
# peak memory: 104.93 MiB, increment: 0.00 MiB
# end forward
# peak memory: 104.93 MiB, increment: 0.00 MiB
# peak memory: 104.93 MiB, increment: 0.00 MiB
# =========
# peak memory: 104.93 MiB, increment: 0.00 MiB
# peak memory: 109.89 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 109.89 MiB, increment: 0.00 MiB
# peak memory: 109.93 MiB, increment: 0.00 MiB
# peak memory: 109.93 MiB, increment: 0.00 MiB
# peak memory: 109.93 MiB, increment: 0.00 MiB
# peak memory: 109.93 MiB, increment: 0.00 MiB
# end forward
# peak memory: 95.00 MiB, increment: -14.93 MiB
# peak memory: 95.00 MiB, increment: 0.00 MiB
# =========
# peak memory: 95.00 MiB, increment: 0.00 MiB
# peak memory: 99.96 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 99.96 MiB, increment: 0.00 MiB
# peak memory: 99.97 MiB, increment: 0.00 MiB
# peak memory: 99.97 MiB, increment: 0.00 MiB
# peak memory: 99.98 MiB, increment: 0.00 MiB
# peak memory: 99.98 MiB, increment: 0.00 MiB
# end forward
# peak memory: 99.98 MiB, increment: 0.00 MiB
# peak memory: 99.98 MiB, increment: 0.00 MiB
# =========
# peak memory: 99.98 MiB, increment: 0.00 MiB
# peak memory: 104.94 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 104.94 MiB, increment: 0.00 MiB
# peak memory: 104.95 MiB, increment: 0.00 MiB
# peak memory: 104.95 MiB, increment: 0.00 MiB
# peak memory: 104.95 MiB, increment: 0.00 MiB
# peak memory: 104.95 MiB, increment: 0.00 MiB
# end forward
# peak memory: 104.95 MiB, increment: 0.00 MiB
# peak memory: 104.95 MiB, increment: 0.00 MiB
# =========
# peak memory: 104.95 MiB, increment: 0.00 MiB
# peak memory: 109.91 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 109.91 MiB, increment: 0.00 MiB
# peak memory: 109.91 MiB, increment: 0.00 MiB
# peak memory: 109.91 MiB, increment: 0.00 MiB
# peak memory: 109.91 MiB, increment: 0.00 MiB
# peak memory: 109.91 MiB, increment: 0.00 MiB
# end forward
# peak memory: 109.91 MiB, increment: 0.00 MiB
# peak memory: 109.91 MiB, increment: 0.00 MiB
# =========
# peak memory: 109.91 MiB, increment: 0.00 MiB
# peak memory: 114.87 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 114.87 MiB, increment: 0.00 MiB
# peak memory: 114.87 MiB, increment: 0.00 MiB
# peak memory: 114.87 MiB, increment: 0.00 MiB
# peak memory: 114.87 MiB, increment: 0.00 MiB
# peak memory: 114.87 MiB, increment: 0.00 MiB
# end forward
# peak memory: 114.88 MiB, increment: 0.00 MiB
# peak memory: 114.88 MiB, increment: 0.00 MiB
# =========
# peak memory: 114.88 MiB, increment: 0.00 MiB
# peak memory: 119.84 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 119.84 MiB, increment: 0.00 MiB
# peak memory: 94.96 MiB, increment: -24.88 MiB
# peak memory: 94.96 MiB, increment: 0.01 MiB
# peak memory: 94.96 MiB, increment: 0.00 MiB
# peak memory: 94.97 MiB, increment: 0.00 MiB
# end forward
# peak memory: 94.97 MiB, increment: 0.00 MiB
# peak memory: 94.97 MiB, increment: 0.00 MiB
# =========
# peak memory: 94.97 MiB, increment: 0.00 MiB
# peak memory: 99.93 MiB, increment: 0.00 MiB
# begin forward
# peak memory: 99.94 MiB, increment: 0.00 MiB
# peak memory: 97.39 MiB, increment: -2.56 MiB
# peak memory: 97.39 MiB, increment: 0.00 MiB
# peak memory: 97.39 MiB, increment: 0.00 MiB
# peak memory: 97.39 MiB, increment: 0.00 MiB
# end forward
# peak memory: 97.39 MiB, increment: 0.00 MiB
# peak memory: 97.39 MiB, increment: 0.00 MiB
# =========

# %%
# debugging memory problems
m = 130000
net = LsqNonneg(m, 20)
for i in range(100):
    # %memit
    inputs = Variable(torch.randn(10, m))
    # %memit
    S = net(inputs)
    #loss = torch.sum(S)
    loss.backward()
    # %memit
