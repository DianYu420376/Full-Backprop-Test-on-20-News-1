# %%
'''
Test on filtered 20NewsGroup dataset
semi_60 one layer
'''
save_PATH = 'saved_data/'
save_filename = 'semi_60_one_layer_pinv'

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
import numpy as np
import sys
package_dir = '../full_backprop_package/'
sys.path.append(package_dir)
from deep_nmf import Deep_NMF, Fro_Norm
from pinv import PinvF
from writer import Writer

# %%
from data_loading import sparsedata_L2, data, Y1

# %%
n = data.shape[0]
m = data.shape[1]
k1 = 20
k2 = 6
net = Deep_NMF([m, k1])
criterion = Fro_Norm()
pinv = PinvF.apply
dataset = sparsedata_L2(1000*data, 1000*Y1)

# %%
lr = 100000
batchsize = 150
lambd = 1e-4
epoch = 11
loss_lst = []
for epo in range(epoch):
    total_loss = 0
    dataloader = torch.utils.data.DataLoader(dataset, batch_size = batchsize, shuffle = True)
    for (i,(inputs, label)) in enumerate(dataloader):
        net.zero_grad()
        
        inputs = torch.reshape(inputs, [inputs.shape[0], inputs.shape[2]])
        label = torch.reshape(label, [label.shape[0], label.shape[2]])
        inputs, label = Variable(inputs), Variable(label.double())
        
        S_lst = net(inputs)
        S = S_lst[-1]
        #B = torch.mm(pinv(S), label)
        #pred = torch.mm(S,B)
        
        loss1 = criterion(torch.mm(S, net.lsqnonneglst[0].A), inputs)
        #loss2 = criterion(pred, label)
        #loss = loss1 + lambd*loss2
        print('epoch = ', epo, 'batch = ',i)
        #print(loss.data, loss1.data, lambd*loss2.data)
        print(loss1.data)
        sys.stdout.flush()
        #loss_lst.append(loss.data)
        #total_loss += loss.data
        
        loss1.backward()
        for A in net.parameters():
            A.data = A.data.sub_(lr*A.grad.data)
            A.data = A.data.clamp(min = 0)

    print('epoch = ', epo)
    print('total_loss = ', total_loss)
# Out:
# epoch =  0 batch =  0
# tensor(7.7851, dtype=torch.float64)
# epoch =  0 batch =  1
# tensor(7.9458, dtype=torch.float64)
# epoch =  0 batch =  2
# tensor(7.9460, dtype=torch.float64)
# epoch =  0 batch =  3
# tensor(7.8918, dtype=torch.float64)
# epoch =  0 batch =  4
# tensor(7.7310, dtype=torch.float64)
# epoch =  0 batch =  5
# tensor(8.0529, dtype=torch.float64)
# epoch =  0 batch =  6
# tensor(7.7310, dtype=torch.float64)
# epoch =  0 batch =  7
# tensor(7.8383, dtype=torch.float64)
# epoch =  0 batch =  8
# tensor(7.9996, dtype=torch.float64)
# epoch =  0 batch =  9
# tensor(7.6237, dtype=torch.float64)
# epoch =  0 batch =  10
# tensor(7.8377, dtype=torch.float64)
# epoch =  0 batch =  11
# tensor(7.8376, dtype=torch.float64)
# epoch =  0 batch =  12
# tensor(7.8378, dtype=torch.float64)
# epoch =  0 batch =  13
# tensor(7.8379, dtype=torch.float64)
# epoch =  0 batch =  14
# tensor(7.7837, dtype=torch.float64)
# epoch =  0 batch =  15
# tensor(7.8373, dtype=torch.float64)
# epoch =  0 batch =  16
# tensor(7.8368, dtype=torch.float64)
# epoch =  0 batch =  17
# tensor(7.8363, dtype=torch.float64)
# epoch =  0 batch =  18
# tensor(7.9424, dtype=torch.float64)
# epoch =  0 batch =  19
# tensor(7.7812, dtype=torch.float64)
# epoch =  0 batch =  20
# tensor(7.6728, dtype=torch.float64)
# epoch =  0 batch =  21
# tensor(7.8311, dtype=torch.float64)
# epoch =  0 batch =  22
# tensor(7.8817, dtype=torch.float64)
# epoch =  0 batch =  23
# tensor(7.8259, dtype=torch.float64)
# epoch =  0 batch =  24
# tensor(7.9812, dtype=torch.float64)
# epoch =  0 batch =  25
# tensor(7.8194, dtype=torch.float64)
# epoch =  0 batch =  26
# tensor(7.6502, dtype=torch.float64)
# epoch =  0 batch =  27
# tensor(7.7514, dtype=torch.float64)
# epoch =  0 batch =  28
# tensor(7.6912, dtype=torch.float64)
# epoch =  0 batch =  29
# tensor(7.6320, dtype=torch.float64)
# epoch =  0 batch =  30
# tensor(7.7802, dtype=torch.float64)
# epoch =  0 batch =  31
# tensor(7.5757, dtype=torch.float64)
# epoch =  0 batch =  32
# tensor(7.8719, dtype=torch.float64)
# epoch =  0 batch =  33
# tensor(7.7680, dtype=torch.float64)
# epoch =  0 batch =  34
# tensor(7.7691, dtype=torch.float64)
# epoch =  0 batch =  35
# tensor(7.7637, dtype=torch.float64)
# epoch =  0 batch =  36
# tensor(7.6487, dtype=torch.float64)
# epoch =  0 batch =  37
# tensor(7.7697, dtype=torch.float64)
# epoch =  0 batch =  38
# tensor(7.7510, dtype=torch.float64)
# epoch =  0 batch =  39
# tensor(7.7651, dtype=torch.float64)
# epoch =  0 batch =  40
# tensor(7.7013, dtype=torch.float64)
# epoch =  0 batch =  41
# tensor(7.7872, dtype=torch.float64)
# epoch =  0 batch =  42
# tensor(7.4250, dtype=torch.float64)
# epoch =  0 batch =  43
# tensor(7.7526, dtype=torch.float64)
# epoch =  0 batch =  44
# tensor(7.5882, dtype=torch.float64)
# epoch =  0 batch =  45
# tensor(7.4868, dtype=torch.float64)
# epoch =  0 batch =  46
# tensor(7.7899, dtype=torch.float64)
# epoch =  0 batch =  47
# tensor(7.7555, dtype=torch.float64)
# epoch =  0 batch =  48
# tensor(7.6963, dtype=torch.float64)
# epoch =  0 batch =  49
# tensor(7.5378, dtype=torch.float64)
# epoch =  0 batch =  50
# tensor(7.8109, dtype=torch.float64)
# epoch =  0 batch =  51
# tensor(7.8340, dtype=torch.float64)
# epoch =  0 batch =  52
# tensor(7.8037, dtype=torch.float64)
# epoch =  0 batch =  53
# tensor(7.7897, dtype=torch.float64)
# epoch =  0 batch =  54
# tensor(7.9209, dtype=torch.float64)
# epoch =  0 batch =  55
# tensor(7.8503, dtype=torch.float64)
# epoch =  0 batch =  56
# tensor(7.7981, dtype=torch.float64)
# epoch =  0 batch =  57
# tensor(7.7548, dtype=torch.float64)
# epoch =  0 batch =  58
# tensor(7.6992, dtype=torch.float64)
# epoch =  0 batch =  59
# tensor(7.5501, dtype=torch.float64)
# epoch =  0 batch =  60
# tensor(7.4256, dtype=torch.float64)
# epoch =  0 batch =  61
# tensor(7.7951, dtype=torch.float64)
# epoch =  0 batch =  62
# tensor(7.6498, dtype=torch.float64)
# epoch =  0 batch =  63
# tensor(7.8634, dtype=torch.float64)
# epoch =  0 batch =  64
# tensor(7.7388, dtype=torch.float64)
# epoch =  0 batch =  65
# tensor(7.7920, dtype=torch.float64)
# epoch =  0 batch =  66
# tensor(7.5347, dtype=torch.float64)
# epoch =  0 batch =  67
# tensor(7.6526, dtype=torch.float64)
# epoch =  0 batch =  68
# tensor(7.8494, dtype=torch.float64)
# epoch =  0 batch =  69
# tensor(7.5947, dtype=torch.float64)
# epoch =  0 batch =  70
# tensor(7.6362, dtype=torch.float64)
# epoch =  0 batch =  71
# tensor(7.7993, dtype=torch.float64)
# epoch =  0 batch =  72
# tensor(7.6432, dtype=torch.float64)
# epoch =  0 batch =  73
# tensor(7.7498, dtype=torch.float64)
# epoch =  0 batch =  74
# tensor(7.6876, dtype=torch.float64)
# epoch =  0 batch =  75
# tensor(7.7397, dtype=torch.float64)
# epoch =  0 batch =  76
# tensor(7.8561, dtype=torch.float64)
# epoch =  0 batch =  77
# tensor(7.6847, dtype=torch.float64)
# epoch =  0 batch =  78
# tensor(7.7073, dtype=torch.float64)
# epoch =  0 batch =  79
# tensor(7.6893, dtype=torch.float64)
# epoch =  0 batch =  80
# tensor(7.6955, dtype=torch.float64)
# epoch =  0 batch =  81
# tensor(7.7499, dtype=torch.float64)
# epoch =  0 batch =  82
# tensor(7.9049, dtype=torch.float64)
# epoch =  0 batch =  83
# tensor(7.6909, dtype=torch.float64)
# epoch =  0 batch =  84
# tensor(7.7529, dtype=torch.float64)
# epoch =  0 batch =  85
# tensor(7.7642, dtype=torch.float64)
# epoch =  0 batch =  86
# tensor(7.6929, dtype=torch.float64)
# epoch =  0 batch =  87
# tensor(7.6460, dtype=torch.float64)
# epoch =  0 batch =  88
# tensor(7.6774, dtype=torch.float64)
# epoch =  0 batch =  89
# tensor(7.9196, dtype=torch.float64)
# epoch =  0 batch =  90
# tensor(7.5888, dtype=torch.float64)
# epoch =  0 batch =  91
# tensor(7.6369, dtype=torch.float64)
# epoch =  0 batch =  92
# tensor(7.5350, dtype=torch.float64)
# epoch =  0 batch =  93
# tensor(7.8413, dtype=torch.float64)
# epoch =  0 batch =  94
# tensor(7.7901, dtype=torch.float64)
# epoch =  0 batch =  95
# tensor(7.7351, dtype=torch.float64)
# epoch =  0 batch =  96
# tensor(7.6936, dtype=torch.float64)
# epoch =  0 batch =  97
# tensor(7.6408, dtype=torch.float64)
# epoch =  0 batch =  98
# tensor(7.7480, dtype=torch.float64)
# epoch =  0 batch =  99
# tensor(7.7933, dtype=torch.float64)
# epoch =  0 batch =  100
# tensor(7.7995, dtype=torch.float64)
# epoch =  0 batch =  101
# tensor(7.6454, dtype=torch.float64)
# epoch =  0 batch =  102
# tensor(7.6956, dtype=torch.float64)
# epoch =  0 batch =  103
# tensor(7.5945, dtype=torch.float64)
# epoch =  0 batch =  104
# tensor(7.6523, dtype=torch.float64)
# epoch =  0 batch =  105
# tensor(7.7604, dtype=torch.float64)
# epoch =  0 batch =  106
# tensor(7.5933, dtype=torch.float64)
# epoch =  0 batch =  107
# tensor(7.5383, dtype=torch.float64)
# epoch =  0 batch =  108
# tensor(7.8042, dtype=torch.float64)
# epoch =  0 batch =  109
# tensor(7.8020, dtype=torch.float64)
# epoch =  0 batch =  110
# tensor(7.7505, dtype=torch.float64)
# epoch =  0 batch =  111
# tensor(7.8848, dtype=torch.float64)
# epoch =  0 batch =  112
# tensor(7.5839, dtype=torch.float64)
# epoch =  0 batch =  113
# tensor(7.8599, dtype=torch.float64)
# epoch =  0 batch =  114
# tensor(7.8006, dtype=torch.float64)
# epoch =  0 batch =  115
# tensor(7.7022, dtype=torch.float64)
# epoch =  0 batch =  116
# tensor(7.8656, dtype=torch.float64)
# epoch =  0 batch =  117
# tensor(7.7258, dtype=torch.float64)
# epoch =  0 batch =  118
# tensor(7.8599, dtype=torch.float64)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-e6b88022cb3d> in <module>()
#      29         #total_loss += loss.data
#      30
# ---> 31         loss1.backward()
#      32         for A in net.parameters():
#      33             A.data = A.data.sub_(lr*A.grad.data)
#
# C:\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# C:\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:
