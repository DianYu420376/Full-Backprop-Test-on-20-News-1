# %%
# debugging the supervised version of deep NMF
import torch
from torch.autograd import Variable
from auxillary_functions import *
from pinv import PinvF
import numpy as np
from writer import Writer
from matplotlib import pyplot as plt
from lsqnonneg_module import LsqNonneg
from deep_nmf import Fro_Norm
from pinv import PinvF

# %%
import Ipynb_importer
from twenty_news_group_data_loading import data, Y, target,L20, L50, L90, sparsedata_cr_entr, sparsedata_L2

# %%
m = data.shape[1]
k = 20
net = LsqNonneg(m, k)
W = Variable(torch.randn(20,20).double(), requires_grad = True)
dataset = sparsedata_L2(data*1000, Y*1000)
cr1 = Fro_Norm()
cr2 = Fro_Norm()

# %%
f = PinvF.apply

# %%
lr_nmf = 10000
lr_clf = 10000
epoch = 1
batchsize = 40
lambd = 1e-4
loss_lst = []
for epo in range(epoch):
    dataloader = torch.utils.data.DataLoader(dataset, batch_size = batchsize, shuffle = True)
    for (i, (inputs, label)) in enumerate(dataloader):
        inputs = inputs.view([inputs.shape[0], inputs.shape[2]])
        label = label.view([label.shape[0], -1])
        inputs, label = Variable(inputs), Variable(label)
        S = net(inputs)
        #W.data = torch.mm(f(S.data),label)
        #pred = torch.mm(S,W.data)
        reconstruction = cr1(inputs, torch.mm(S,net.A))
        #classification = cr2(pred, label)
        loss = reconstruction
        loss.backward()
        print(i, loss.data)
        loss_lst.append(loss.data)
        net.A.data = net.A.data.sub_(lr_nmf*net.A.grad.data)
        net.A.data = net.A.data.clamp(min = 0)
        #W.data = W.data.sub_(lr_clf*W.grad.data)
# Out:
# 0 tensor(7.6812, dtype=torch.float64)
# 1 tensor(7.6808, dtype=torch.float64)
# 2 tensor(7.6773, dtype=torch.float64)
# 3 tensor(7.6742, dtype=torch.float64)
# 4 tensor(7.6629, dtype=torch.float64)
# 5 tensor(7.6152, dtype=torch.float64)
# 6 tensor(7.5054, dtype=torch.float64)
# 7 tensor(7.1981, dtype=torch.float64)
# 8 tensor(6.6699, dtype=torch.float64)
# 9 tensor(5.5456, dtype=torch.float64)
# 10 tensor(5.1951, dtype=torch.float64)
# 11 tensor(4.9704, dtype=torch.float64)
# 12 tensor(5.1487, dtype=torch.float64)
# 13 tensor(4.9445, dtype=torch.float64)
# 14 tensor(5.2443, dtype=torch.float64)
# 15 tensor(4.9713, dtype=torch.float64)
# 16 tensor(4.6128, dtype=torch.float64)
# 17 tensor(5.1268, dtype=torch.float64)
# 18 tensor(5.2617, dtype=torch.float64)
# 19 tensor(4.9978, dtype=torch.float64)
# 20 tensor(4.4814, dtype=torch.float64)
# 21 tensor(4.9679, dtype=torch.float64)
# 22 tensor(4.7714, dtype=torch.float64)
# 23 tensor(4.9582, dtype=torch.float64)
# 24 tensor(5.1522, dtype=torch.float64)
# 25 tensor(5.0294, dtype=torch.float64)
# 26 tensor(5.0822, dtype=torch.float64)
# 27 tensor(4.6148, dtype=torch.float64)
# 28 tensor(4.7512, dtype=torch.float64)
# 29 tensor(4.9934, dtype=torch.float64)
# 30 tensor(4.9020, dtype=torch.float64)
# 31 tensor(4.8271, dtype=torch.float64)
# 32 tensor(4.9429, dtype=torch.float64)
# 33 tensor(4.9942, dtype=torch.float64)
# 34 tensor(4.5757, dtype=torch.float64)
# 35 tensor(5.1870, dtype=torch.float64)
# 36 tensor(5.1367, dtype=torch.float64)
# 37 tensor(4.7058, dtype=torch.float64)
# 38 tensor(5.0309, dtype=torch.float64)
# 39 tensor(5.1828, dtype=torch.float64)
# 40 tensor(4.6200, dtype=torch.float64)
# 41 tensor(5.1453, dtype=torch.float64)
# 42 tensor(5.0261, dtype=torch.float64)
# 43 tensor(5.1005, dtype=torch.float64)
# 44 tensor(4.7652, dtype=torch.float64)
# 45 tensor(4.6317, dtype=torch.float64)
# 46 tensor(5.0346, dtype=torch.float64)
# 47 tensor(5.2938, dtype=torch.float64)
# 48 tensor(4.8408, dtype=torch.float64)
# 49 tensor(5.1340, dtype=torch.float64)
# 50 tensor(5.3111, dtype=torch.float64)
# 51 tensor(4.7688, dtype=torch.float64)
# 52 tensor(4.8543, dtype=torch.float64)
# 53 tensor(4.8161, dtype=torch.float64)
# 54 tensor(4.7881, dtype=torch.float64)
# 55 tensor(4.8588, dtype=torch.float64)
# 56 tensor(4.7693, dtype=torch.float64)
# 57 tensor(4.7075, dtype=torch.float64)
# 58 tensor(5.1227, dtype=torch.float64)
# 59 tensor(4.7009, dtype=torch.float64)
# 60 tensor(5.1633, dtype=torch.float64)
# 61 tensor(4.5262, dtype=torch.float64)
# 62 tensor(4.9428, dtype=torch.float64)
# 63 tensor(4.7085, dtype=torch.float64)
# 64 tensor(4.8101, dtype=torch.float64)
# 65 tensor(4.8095, dtype=torch.float64)
# 66 tensor(4.4923, dtype=torch.float64)
# 67 tensor(4.9113, dtype=torch.float64)
# 68 tensor(4.5465, dtype=torch.float64)
# 69 tensor(4.7577, dtype=torch.float64)
# 70 tensor(4.8182, dtype=torch.float64)
# 71 tensor(5.0255, dtype=torch.float64)
# 72 tensor(4.4521, dtype=torch.float64)
# 73 tensor(5.0257, dtype=torch.float64)
# 74 tensor(4.3183, dtype=torch.float64)
# 75 tensor(4.8108, dtype=torch.float64)
# 76 tensor(5.0516, dtype=torch.float64)
# 77 tensor(4.4878, dtype=torch.float64)
# 78 tensor(4.6995, dtype=torch.float64)
# 79 tensor(4.8215, dtype=torch.float64)
# 80 tensor(4.0927, dtype=torch.float64)
# 81 tensor(4.8804, dtype=torch.float64)
# 82 tensor(4.8372, dtype=torch.float64)
# 83 tensor(4.8132, dtype=torch.float64)
# 84 tensor(4.0225, dtype=torch.float64)
# 85 tensor(4.6254, dtype=torch.float64)
# 86 tensor(4.2576, dtype=torch.float64)
# 87 tensor(4.5109, dtype=torch.float64)
# 88 tensor(4.8778, dtype=torch.float64)
# 89 tensor(4.6274, dtype=torch.float64)
# 90 tensor(4.9171, dtype=torch.float64)
# 91 tensor(4.7759, dtype=torch.float64)
# 92 tensor(4.8551, dtype=torch.float64)
# 93 tensor(4.5225, dtype=torch.float64)
# 94 tensor(4.7992, dtype=torch.float64)
# 95 tensor(4.4427, dtype=torch.float64)
# 96 tensor(4.7959, dtype=torch.float64)
# 97 tensor(4.3009, dtype=torch.float64)
# 98 tensor(4.7114, dtype=torch.float64)
# 99 tensor(4.8960, dtype=torch.float64)
# 100 tensor(4.8349, dtype=torch.float64)
# 101 tensor(4.3646, dtype=torch.float64)
# 102 tensor(4.5060, dtype=torch.float64)
# 103 tensor(4.4099, dtype=torch.float64)
# 104 tensor(4.7361, dtype=torch.float64)
# 105 tensor(4.5947, dtype=torch.float64)
# 106 tensor(4.1186, dtype=torch.float64)
# 107 tensor(4.4429, dtype=torch.float64)
# 108 tensor(4.5917, dtype=torch.float64)
# 109 tensor(4.7800, dtype=torch.float64)
# 110 tensor(4.4417, dtype=torch.float64)
# 111 tensor(4.8664, dtype=torch.float64)
# 112 tensor(4.4411, dtype=torch.float64)
# 113 tensor(4.7310, dtype=torch.float64)
# 114 tensor(4.3908, dtype=torch.float64)
# 115 tensor(4.2752, dtype=torch.float64)
# 116 tensor(4.1020, dtype=torch.float64)
# 117 tensor(4.1781, dtype=torch.float64)
# 118 tensor(4.8242, dtype=torch.float64)
# 119 tensor(4.8226, dtype=torch.float64)
# 120 tensor(4.4473, dtype=torch.float64)
# 121 tensor(4.5196, dtype=torch.float64)
# 122 tensor(4.5896, dtype=torch.float64)
# 123 tensor(4.3936, dtype=torch.float64)
# 124 tensor(4.7933, dtype=torch.float64)
# 125 tensor(4.2936, dtype=torch.float64)
# 126 tensor(4.6003, dtype=torch.float64)
# 127 tensor(5.1533, dtype=torch.float64)
# 128 tensor(4.6654, dtype=torch.float64)
# 129 tensor(4.4225, dtype=torch.float64)
# 130 tensor(4.6744, dtype=torch.float64)
# 131 tensor(4.5138, dtype=torch.float64)
# 132 tensor(5.0501, dtype=torch.float64)
# 133 tensor(4.7016, dtype=torch.float64)
# 134 tensor(5.1717, dtype=torch.float64)
# 135 tensor(4.7948, dtype=torch.float64)
# 136 tensor(4.3391, dtype=torch.float64)
# 137 tensor(4.8050, dtype=torch.float64)
# 138 tensor(4.3914, dtype=torch.float64)
# 139 tensor(4.6767, dtype=torch.float64)
# 140 tensor(4.5105, dtype=torch.float64)
# 141 tensor(4.7736, dtype=torch.float64)
# 142 tensor(4.3186, dtype=torch.float64)
# 143 tensor(4.8190, dtype=torch.float64)
# 144 tensor(4.3213, dtype=torch.float64)
# 145 tensor(4.8092, dtype=torch.float64)
# 146 tensor(4.7067, dtype=torch.float64)
# 147 tensor(4.3566, dtype=torch.float64)
# 148 tensor(4.4592, dtype=torch.float64)
# 149 tensor(4.6858, dtype=torch.float64)
# 150 tensor(4.4587, dtype=torch.float64)
# 151 tensor(4.1077, dtype=torch.float64)
# 152 tensor(3.9792, dtype=torch.float64)
# 153 tensor(4.6715, dtype=torch.float64)
# 154 tensor(4.4863, dtype=torch.float64)
# 155 tensor(4.3596, dtype=torch.float64)
# 156 tensor(4.6596, dtype=torch.float64)
# 157 tensor(4.4776, dtype=torch.float64)
# 158 tensor(4.5427, dtype=torch.float64)
# 159 tensor(4.2252, dtype=torch.float64)
# 160 tensor(4.5599, dtype=torch.float64)
# 161 tensor(4.7331, dtype=torch.float64)
# 162 tensor(4.2558, dtype=torch.float64)
# 163 tensor(4.2231, dtype=torch.float64)
# 164 tensor(4.4418, dtype=torch.float64)
# 165 tensor(4.5125, dtype=torch.float64)
# 166 tensor(4.2038, dtype=torch.float64)
# 167 tensor(4.2551, dtype=torch.float64)
# 168 tensor(4.3111, dtype=torch.float64)
# 169 tensor(4.4200, dtype=torch.float64)
# 170 tensor(4.9260, dtype=torch.float64)
# 171 tensor(4.3469, dtype=torch.float64)
# 172 tensor(4.1118, dtype=torch.float64)
# 173 tensor(4.5405, dtype=torch.float64)
# 174 tensor(4.4828, dtype=torch.float64)
# 175 tensor(4.5560, dtype=torch.float64)
# 176 tensor(4.1973, dtype=torch.float64)
# 177 tensor(4.2361, dtype=torch.float64)
# 178 tensor(4.5485, dtype=torch.float64)
# 179 tensor(4.6519, dtype=torch.float64)
# 180 tensor(4.4099, dtype=torch.float64)
# 181 tensor(4.5310, dtype=torch.float64)
# 182 tensor(4.2433, dtype=torch.float64)
# 183 tensor(4.5305, dtype=torch.float64)
# 184 tensor(4.6270, dtype=torch.float64)
# 185 tensor(4.4601, dtype=torch.float64)
# 186 tensor(4.7101, dtype=torch.float64)
# 187 tensor(4.3905, dtype=torch.float64)
# 188 tensor(4.3633, dtype=torch.float64)
# 189 tensor(4.2274, dtype=torch.float64)
# 190 tensor(4.1397, dtype=torch.float64)
# 191 tensor(4.1751, dtype=torch.float64)
# 192 tensor(4.2039, dtype=torch.float64)
# 193 tensor(4.3692, dtype=torch.float64)
# 194 tensor(4.1077, dtype=torch.float64)
# 195 tensor(4.1601, dtype=torch.float64)
# 196 tensor(4.4985, dtype=torch.float64)
# 197 tensor(4.6850, dtype=torch.float64)
# 198 tensor(4.5914, dtype=torch.float64)
# 199 tensor(4.2210, dtype=torch.float64)
# 200 tensor(4.4812, dtype=torch.float64)
# 201 tensor(3.8374, dtype=torch.float64)
# 202 tensor(4.4802, dtype=torch.float64)
# 203 tensor(4.3267, dtype=torch.float64)
# 204 tensor(4.3006, dtype=torch.float64)
# 205 tensor(3.7891, dtype=torch.float64)
# 206 tensor(4.0722, dtype=torch.float64)
# 207 tensor(4.3522, dtype=torch.float64)
# 208 tensor(4.5727, dtype=torch.float64)
# 209 tensor(4.2440, dtype=torch.float64)
# 210 tensor(4.3172, dtype=torch.float64)
# 211 tensor(4.6606, dtype=torch.float64)
# 212 tensor(3.8762, dtype=torch.float64)
# 213 tensor(4.4918, dtype=torch.float64)
# 214 tensor(4.3437, dtype=torch.float64)
# 215 tensor(4.4213, dtype=torch.float64)
# 216 tensor(4.6481, dtype=torch.float64)
# 217 tensor(4.6036, dtype=torch.float64)
# 218 tensor(4.2865, dtype=torch.float64)
# 219 tensor(4.0416, dtype=torch.float64)
# 220 tensor(4.4546, dtype=torch.float64)
# 221 tensor(4.2921, dtype=torch.float64)
# 222 tensor(4.2412, dtype=torch.float64)
# 223 tensor(4.2043, dtype=torch.float64)
# 224 tensor(4.4723, dtype=torch.float64)
# 225 tensor(4.7154, dtype=torch.float64)
# 226 tensor(4.2479, dtype=torch.float64)
# 227 tensor(4.2109, dtype=torch.float64)
# 228 tensor(4.1236, dtype=torch.float64)
# 229 tensor(4.3560, dtype=torch.float64)
# 230 tensor(4.1068, dtype=torch.float64)
# 231 tensor(4.4448, dtype=torch.float64)
# 232 tensor(4.3840, dtype=torch.float64)
# 233 tensor(4.3346, dtype=torch.float64)
# 234 tensor(4.0995, dtype=torch.float64)
# 235 tensor(4.7803, dtype=torch.float64)
# 236 tensor(4.2865, dtype=torch.float64)
# 237 tensor(4.0265, dtype=torch.float64)
# 238 tensor(4.1218, dtype=torch.float64)
# 239 tensor(4.2356, dtype=torch.float64)
# 240 tensor(4.2135, dtype=torch.float64)
# 241 tensor(4.1100, dtype=torch.float64)
# 242 tensor(4.0625, dtype=torch.float64)
# 243 tensor(4.3055, dtype=torch.float64)
# 244 tensor(4.0270, dtype=torch.float64)
# 245 tensor(4.3129, dtype=torch.float64)
# 246 tensor(4.3264, dtype=torch.float64)
# 247 tensor(4.1596, dtype=torch.float64)
# 248 tensor(4.4087, dtype=torch.float64)
# 249 tensor(3.8828, dtype=torch.float64)
# 250 tensor(4.2121, dtype=torch.float64)
# 251 tensor(4.0394, dtype=torch.float64)
# 252 tensor(4.6882, dtype=torch.float64)
# 253 tensor(4.0594, dtype=torch.float64)
# 254 tensor(4.3366, dtype=torch.float64)
# 255 tensor(4.7131, dtype=torch.float64)
# 256 tensor(4.3194, dtype=torch.float64)
# 257 tensor(4.4531, dtype=torch.float64)
# 258 tensor(4.1334, dtype=torch.float64)
# 259 tensor(3.8634, dtype=torch.float64)
# 260 tensor(4.3016, dtype=torch.float64)
# 261 tensor(4.1501, dtype=torch.float64)
# 262 tensor(4.2726, dtype=torch.float64)
# 263 tensor(4.1862, dtype=torch.float64)
# 264 tensor(4.5732, dtype=torch.float64)
# 265 tensor(3.9551, dtype=torch.float64)
# 266 tensor(4.1992, dtype=torch.float64)
# 267 tensor(4.5752, dtype=torch.float64)
# 268 tensor(4.4943, dtype=torch.float64)
# 269 tensor(4.3461, dtype=torch.float64)
# 270 tensor(4.2940, dtype=torch.float64)
# 271 tensor(4.4792, dtype=torch.float64)
# 272 tensor(4.5266, dtype=torch.float64)
# 273 tensor(4.2751, dtype=torch.float64)
# 274 tensor(3.7829, dtype=torch.float64)
# 275 tensor(4.1697, dtype=torch.float64)
# 276 tensor(4.2668, dtype=torch.float64)
# 277 tensor(4.3056, dtype=torch.float64)
# 278 tensor(3.8733, dtype=torch.float64)
# 279 tensor(4.2519, dtype=torch.float64)
# 280 tensor(3.7713, dtype=torch.float64)
# 281 tensor(4.1196, dtype=torch.float64)
# 282 tensor(4.0618, dtype=torch.float64)
# 283 tensor(3.9982, dtype=torch.float64)
# 284 tensor(3.9637, dtype=torch.float64)
# 285 tensor(4.2303, dtype=torch.float64)
# 286 tensor(4.6489, dtype=torch.float64)
# 287 tensor(4.3778, dtype=torch.float64)
# 288 tensor(3.9893, dtype=torch.float64)
# 289 tensor(4.5324, dtype=torch.float64)
# 290 tensor(4.3497, dtype=torch.float64)
# 291 tensor(4.2325, dtype=torch.float64)
# 292 tensor(3.9846, dtype=torch.float64)
# 293 tensor(3.9420, dtype=torch.float64)
# 294 tensor(4.2263, dtype=torch.float64)
# 295 tensor(4.3392, dtype=torch.float64)
# 296 tensor(4.3389, dtype=torch.float64)
# 297 tensor(4.2231, dtype=torch.float64)
# 298 tensor(4.3951, dtype=torch.float64)
# 299 tensor(3.9702, dtype=torch.float64)
# 300 tensor(4.4365, dtype=torch.float64)
# 301 tensor(4.3536, dtype=torch.float64)
# 302 tensor(4.4335, dtype=torch.float64)
# 303 tensor(4.0317, dtype=torch.float64)
# 304 tensor(3.8545, dtype=torch.float64)
# 305 tensor(4.3345, dtype=torch.float64)
# 306 tensor(4.1214, dtype=torch.float64)
# 307 tensor(4.0237, dtype=torch.float64)
# 308 tensor(3.8111, dtype=torch.float64)
# 309 tensor(4.0389, dtype=torch.float64)
# 310 tensor(3.7660, dtype=torch.float64)
# 311 tensor(4.1854, dtype=torch.float64)
# 312 tensor(3.8038, dtype=torch.float64)
# 313 tensor(3.8074, dtype=torch.float64)
# 314 tensor(4.4489, dtype=torch.float64)
# 315 tensor(3.7171, dtype=torch.float64)
# 316 tensor(4.0448, dtype=torch.float64)
# 317 tensor(3.8082, dtype=torch.float64)
# 318 tensor(4.4188, dtype=torch.float64)
# 319 tensor(3.8634, dtype=torch.float64)
# 320 tensor(4.6085, dtype=torch.float64)
# 321 tensor(4.2801, dtype=torch.float64)
# 322 tensor(4.1380, dtype=torch.float64)
# 323 tensor(3.9056, dtype=torch.float64)
# 324 tensor(4.2848, dtype=torch.float64)
# 325 tensor(3.8486, dtype=torch.float64)
# 326 tensor(4.1504, dtype=torch.float64)
# 327 tensor(4.0797, dtype=torch.float64)
# 328 tensor(4.4346, dtype=torch.float64)
# 329 tensor(3.6833, dtype=torch.float64)
# 330 tensor(3.9505, dtype=torch.float64)
# 331 tensor(3.9595, dtype=torch.float64)
# 332 tensor(4.3055, dtype=torch.float64)
# 333 tensor(4.1290, dtype=torch.float64)
# 334 tensor(3.8101, dtype=torch.float64)
# 335 tensor(3.8458, dtype=torch.float64)
# 336 tensor(4.5791, dtype=torch.float64)
# 337 tensor(4.2883, dtype=torch.float64)
# 338 tensor(3.9422, dtype=torch.float64)
# 339 tensor(3.5739, dtype=torch.float64)
# 340 tensor(4.4544, dtype=torch.float64)
# 341 tensor(4.0436, dtype=torch.float64)
# 342 tensor(4.0350, dtype=torch.float64)
# 343 tensor(4.0991, dtype=torch.float64)
# 344 tensor(4.2776, dtype=torch.float64)
# 345 tensor(4.0603, dtype=torch.float64)
# 346 tensor(4.2038, dtype=torch.float64)
# 347 tensor(3.9059, dtype=torch.float64)
# 348 tensor(4.5555, dtype=torch.float64)
# 349 tensor(4.6842, dtype=torch.float64)
# 350 tensor(3.8647, dtype=torch.float64)
# 351 tensor(3.9569, dtype=torch.float64)
# 352 tensor(3.8702, dtype=torch.float64)
# 353 tensor(4.0522, dtype=torch.float64)
# 354 tensor(3.8664, dtype=torch.float64)
# 355 tensor(4.6441, dtype=torch.float64)
# 356 tensor(4.0219, dtype=torch.float64)
# 357 tensor(3.9751, dtype=torch.float64)
# 358 tensor(4.2769, dtype=torch.float64)
# 359 tensor(3.6514, dtype=torch.float64)
# 360 tensor(4.1078, dtype=torch.float64)
# 361 tensor(3.9737, dtype=torch.float64)
# 362 tensor(3.7736, dtype=torch.float64)
# 363 tensor(4.2237, dtype=torch.float64)
# 364 tensor(4.2200, dtype=torch.float64)
# 365 tensor(4.5529, dtype=torch.float64)
# 366 tensor(4.2059, dtype=torch.float64)
# 367 tensor(4.2170, dtype=torch.float64)
# 368 tensor(3.8072, dtype=torch.float64)
# 369 tensor(4.3186, dtype=torch.float64)
# 370 tensor(4.3464, dtype=torch.float64)
# 371 tensor(4.1668, dtype=torch.float64)
# 372 tensor(3.9689, dtype=torch.float64)
# 373 tensor(4.3552, dtype=torch.float64)
# 374 tensor(4.0798, dtype=torch.float64)
# 375 tensor(4.2017, dtype=torch.float64)
# 376 tensor(3.9239, dtype=torch.float64)
# 377 tensor(4.4147, dtype=torch.float64)
# 378 tensor(4.1823, dtype=torch.float64)
# 379 tensor(4.3651, dtype=torch.float64)
# 380 tensor(4.5712, dtype=torch.float64)
# 381 tensor(3.9669, dtype=torch.float64)
# 382 tensor(4.3005, dtype=torch.float64)
# 383 tensor(3.7255, dtype=torch.float64)
# 384 tensor(3.7989, dtype=torch.float64)
# 385 tensor(3.9968, dtype=torch.float64)
# 386 tensor(4.3770, dtype=torch.float64)
# 387 tensor(4.0656, dtype=torch.float64)
# 388 tensor(4.2890, dtype=torch.float64)
# 389 tensor(4.4770, dtype=torch.float64)
# 390 tensor(4.2320, dtype=torch.float64)
# 391 tensor(4.3518, dtype=torch.float64)
# 392 tensor(4.3355, dtype=torch.float64)
# 393 tensor(4.0918, dtype=torch.float64)
# 394 tensor(4.2740, dtype=torch.float64)
# 395 tensor(4.3411, dtype=torch.float64)
# 396 tensor(4.0110, dtype=torch.float64)
# 397 tensor(4.1793, dtype=torch.float64)
# 398 tensor(3.9533, dtype=torch.float64)
# 399 tensor(4.6929, dtype=torch.float64)
# 400 tensor(4.2864, dtype=torch.float64)
# 401 tensor(4.3555, dtype=torch.float64)
# 402 tensor(3.8727, dtype=torch.float64)
# 403 tensor(4.0003, dtype=torch.float64)
# 404 tensor(3.9354, dtype=torch.float64)
# 405 tensor(4.0362, dtype=torch.float64)
# 406 tensor(4.1856, dtype=torch.float64)
# 407 tensor(3.6656, dtype=torch.float64)
# 408 tensor(4.0467, dtype=torch.float64)
# 409 tensor(3.6832, dtype=torch.float64)
# 410 tensor(4.4363, dtype=torch.float64)
# 411 tensor(4.3129, dtype=torch.float64)
# 412 tensor(4.6416, dtype=torch.float64)
# 413 tensor(3.7408, dtype=torch.float64)
# 414 tensor(4.1847, dtype=torch.float64)
# 415 tensor(4.4921, dtype=torch.float64)
# 416 tensor(3.9553, dtype=torch.float64)
# 417 tensor(3.7715, dtype=torch.float64)
# 418 tensor(3.9779, dtype=torch.float64)
# 419 tensor(3.7069, dtype=torch.float64)
# 420 tensor(3.5613, dtype=torch.float64)
# 421 tensor(4.1784, dtype=torch.float64)
# 422 tensor(4.2805, dtype=torch.float64)
# 423 tensor(4.6386, dtype=torch.float64)
# 424 tensor(3.9015, dtype=torch.float64)
# 425 tensor(4.3685, dtype=torch.float64)
# 426 tensor(4.3606, dtype=torch.float64)
# 427 tensor(4.2915, dtype=torch.float64)
# 428 tensor(4.3906, dtype=torch.float64)
# 429 tensor(4.1016, dtype=torch.float64)
# 430 tensor(3.9036, dtype=torch.float64)
# 431 tensor(3.7994, dtype=torch.float64)
# 432 tensor(3.8632, dtype=torch.float64)
# 433 tensor(3.9404, dtype=torch.float64)
# 434 tensor(3.5122, dtype=torch.float64)
# 435 tensor(4.1698, dtype=torch.float64)
# 436 tensor(3.7546, dtype=torch.float64)
# 437 tensor(3.8890, dtype=torch.float64)
# 438 tensor(3.7618, dtype=torch.float64)
# 439 tensor(4.2781, dtype=torch.float64)
# 440 tensor(4.2170, dtype=torch.float64)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1c723cabaa58> in <module>()
#      17         #classification = cr2(pred, label)
#      18         loss = reconstruction
# ---> 19         loss.backward()
#      20         print(i, loss.data)
#      21         loss_lst.append(loss.data)
#
# C:\Anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# C:\Anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:

# %%
torch.sum(net.A.data[0,:] != 0)
# Out:
# tensor(14758)

# %%
print(torch.min(torch.abs(net.A.data/net.A.grad.data)))
print(torch.min(torch.abs(W.data/W.grad.data)))
# Out:
# tensor(0., dtype=torch.float64)
# tensor(3697.4496, dtype=torch.float64)

# %%
A = net.A.data
